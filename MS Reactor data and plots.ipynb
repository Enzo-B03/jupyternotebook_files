# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_excel('C:\\Users\\v.t.flores\\Documents\\Tesfile_106G03 data nov2018.xlsx')

# %%
df
# Out:
#                     time  106LIC003@PV  106LIC004@PV  106LIC005@PV  \
# 0    2018-11-01 00:05:00     89.119751     92.519997     92.268143
# 1    2018-11-01 00:10:00     88.847702     92.540001     92.337334
# 2    2018-11-01 00:15:00     89.087128     92.610001     92.377495
# 3    2018-11-01 00:20:00     89.267494     92.709999     92.310173
# 4    2018-11-01 00:25:00     89.318558     92.550003     92.422745
# ...                  ...           ...           ...           ...
# 8629 2018-11-30 23:10:00     90.320000     90.559998     88.051514
# 8630 2018-11-30 23:15:00     90.669998     90.620003     88.122299
# 8631 2018-11-30 23:20:00     90.050003     90.809998     88.305626
# 8632 2018-11-30 23:25:00     89.769997     90.809998     88.535561
# 8633 2018-11-30 23:30:00     89.760002     90.839996     88.561340
#
#       106LIC006@PV  106LT003B@PV
# 0        90.148880     89.000000
# 1        90.330124     88.620003
# 2        90.285851     88.900002
# ...

# %%
fig = sns.pairplot(df.head(50))
fig.savefig('MS_Rxtrs_Pairplot.png', dpi=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-13240f467855> in <module>
#       1 fig = sns.pairplot(df.head(50))
#       2 fig.savefig('MS_Rxtrs_Pairplot.png', dpi=200)
# ----> 3 pwd()
#
# NameError: name 'pwd' is not defined

# %%
plt.savefig('MS_Rxtrs_Pairplot.png', dpi=200)

# %%
df_msrxtr = pd.read_excel('C:\\Users\\v.t.flores\\Documents\\MS_RxtrData_Feb2018.xlsx', skiprows=0)
df_msrxtr.dropna(how='any', axis=0).info()
df_msrxtr
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8058 entries, 0 to 8057
# Data columns (total 10 columns):
# time            8058 non-null datetime64[ns]
# 106LIC003@PV    8058 non-null float64
# 106LIC004@PV    8058 non-null float64
# 106LIC005@PV    8058 non-null float64
# 106LIC006@PV    8058 non-null float64
# 106LT003B@PV    8058 non-null float64
# 106PI002.PV     8058 non-null float64
# 106PI003.PV     8058 non-null float64
# 106PI004.PV     8058 non-null float64
# 106PI005.PV     8058 non-null float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 692.5 KB
#                     time  106LIC003@PV  106LIC004@PV  106LIC005@PV  \
# 0    2018-02-01 00:05:00     89.739998     92.540001     90.121140
# 1    2018-02-01 00:10:00     90.099998     92.260002     90.123581
# 2    2018-02-01 00:15:00     90.059998     92.040001     90.218987
# 3    2018-02-01 00:20:00     89.949997     92.070000     90.228233
# ...

# %%
#df_msrxtr

# %%
pairplot_2 = sns.pairplot(df_msrxtr)
pairplot_2.savefig('rxtr pairplot LvlP.png')

# %%
sns_plot = sns.scatterplot(x="106LIC003@PV", y="106LT003B@PV", data=df_msrxtr, 
                alpha=1)
sns_plot.savefig('lvl vs prssr.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-2d3985f2fd8b> in <module>
#       1 sns_plot = sns.scatterplot(x="106LIC003@PV", y="106LT003B@PV", data=df_msrxtr,
#       2                 alpha=1)
# ----> 3 sns_plot.savefig('lvl vs prssr.png')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
sns.scatterplot(x="106LIC003@PV", y="106PI002.PV", data=df_msrxtr, 
                alpha=1)
fig.savefig('C:\\Users\\v.t.flores\\Documents\\lvl vs prssr.png')

# %%
df_lvsp = df_msrxtr[['106LIC003@PV','106PI002.PV']]

# %%
fig.savefig('C:\\Users\\v.t.flores\\Documents\\lvl vs prssr.png')

# %%
df_msrxtr.index
# Out:
# RangeIndex(start=0, stop=8066, step=1)

# %%
df_lvsp.corr()
# Out:
#               106LIC003@PV  106PI002.PV
# 106LIC003@PV      1.000000    -0.392898
# 106PI002.PV      -0.392898     1.000000

# %%
df_lvsp2 = df_msrxtr[['106LIC003@PV','106LT003B@PV']]

# %%
df_lvsp2.corr()
# Out:
#               106LIC003@PV  106LT003B@PV
# 106LIC003@PV       1.00000       0.98344
# 106LT003B@PV       0.98344       1.00000

# %%
df_msrxtr.iloc[8060]
# Out:
# time                NaT
# 106LIC003@PV        NaN
# 106LIC004@PV        NaN
# 106LIC005@PV        NaN
# 106LIC006@PV        NaN
# 106LT003B@PV        NaN
# 106PI002.PV     280.584
# 106PI003.PV     252.936
# 106PI004.PV     226.392
# 106PI005.PV      209.28
# Name: 8060, dtype: object

# %%
df_msrxtr.dropna(how='any', inplace=True)
