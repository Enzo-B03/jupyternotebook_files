# %%
#exc1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from dateutil.parser import parse
from itertools import compress
from collections import OrderedDict
from datetime import date

# %%
#exc2
#Sheet nov2019_Mg_PS

#Step1: Load the Data for the month
df_nov2019_Mg_PS =  pd.read_excel(r'C:\Users\v.t.flores\Documents\Analysis_November2019_MSdataCLEAN.xlsx', sheet_name='NOV19Datetime_Mg_PS', index_col=False)

#Step2: Parse the DATETIME column
df_nov2019_Mg_PS['DATETIME'] = df_nov2019_Mg_PS['DATETIME'].apply(lambda x: parse(str(x)))

#Step3: Set the DATETIME column as the index
df_nov2019_Mg_PS.set_index('DATETIME', inplace=True)

print('DONE. nov2019_Mg_PS')
# Out:
# DONE. nov2019_Mg_PS

# %%
#exc3
#Sheet 106FT02A_spcl

#Step1: Load the Data for the month
df_106FT02A_spcl =  pd.read_excel(r'C:\Users\v.t.flores\Documents\Analysis_November2019_MSdataCLEAN.xlsx', sheet_name='106FT02A_spcl', index_col=False)

#Step2: Parse the DATETIME column
df_106FT02A_spcl['DATETIME'] = df_106FT02A_spcl['DATETIME'].apply(lambda x: parse(x))

#Step3: Set the DATETIME column as the index
df_106FT02A_spcl.set_index('DATETIME', inplace=True)

print('DONE. 106FT02A_spcl')
# Out:
# DONE. 106FT02A_spcl

# %%
#exc4
#Sheet 106FT02B_spcl

#Step1: Load the Data for the month
df_106FT02B_spcl = pd.read_excel(r'C:\Users\v.t.flores\Documents\Analysis_November2019_MSdataCLEAN.xlsx', sheet_name='106FT02B_spcl', index_col=False)



#Step2: Parse the DATETIME column
df_106FT02B_spcl['DATETIME'] = df_106FT02B_spcl['DATETIME'].apply(lambda x: parse(x))

#Step3: Set the DATETIME column as the index
df_106FT02B_spcl.set_index('DATETIME', inplace=True)

print('DONE. 106FT02B_spcl')
# Out:
# DONE. 106FT02B_spcl

# %%
#exc5
#Sheet From Pi
#Step1: Load the Data for the month
df_nov2019Pi = pd.read_excel(r'C:\Users\v.t.flores\Documents\Analysis_November2019_MSdataCLEAN.xlsx', sheet_name='From Pi', index_col=False)

#Drop the row[1]
df_nov2019Pi = df_nov2019Pi.drop(df_nov2019Pi.index[0])

#Step2: Parse the DATETIME column
df_nov2019Pi['DATETIME'] = df_nov2019Pi['DATETIME'].apply(lambda x: parse(str(x)))

df_nov2019Pi.set_index('DATETIME', inplace=True)

print('Done')
# Out:
# Done

# %%
#exc6
#This code merges the formatted data from the three sheets to on single dataframe named df_comb

df_com_Pi_FT02A = df_nov2019Pi.join(df_106FT02A_spcl, how='outer')
df_com_Mg_FT02B = df_nov2019_Mg_PS.join(df_106FT02B_spcl, how='outer')
df_comb = df_com_Pi_FT02A.join(df_com_Mg_FT02B, how='outer')

# %%
#df_comb.to_excel(r'C:\Users\v.t.flores\Documents\201911Data_Mg_Inv.xlsx')

# %%
#exc7
#finding peaks FT for A_filtration time

df_comb['A_t_FEED'] = pd.to_numeric(df_comb['A_t_FEED'], errors='coerce')
a = np.diff(np.sign(np.diff(df_comb['A_t_FEED']))).nonzero()[0] + 1               # local min & max
b = (np.diff(np.sign(np.diff(df_comb['A_t_FEED']))) > 0).nonzero()[0] + 1         # local min
c = (np.diff(np.sign(np.diff(df_comb['A_t_FEED']))) < 0).nonzero()[0] + 1         # local max
# +1 due to the fact that diff reduces the original index number


#finding peaks FT for A_N2 Dry time

df_comb['A_t_DRY'] = pd.to_numeric(df_comb['A_t_DRY'], errors='coerce')
d = np.diff(np.sign(np.diff(df_comb['A_t_DRY']))).nonzero()[0] + 1               # local min & max
e = (np.diff(np.sign(np.diff(df_comb['A_t_DRY']))) > 0).nonzero()[0] + 1         # local min
f = (np.diff(np.sign(np.diff(df_comb['A_t_DRY']))) < 0).nonzero()[0] + 1         # local max
# +1 due to the fact that diff reduces the original index number
print('done')

#Use b as the starting index and f as the ending index for one full cylcle of Filtration to N2 Drying

#-----------------------------------------------------------------------------------------------------------------------

#This code here collects the index range for the each cycle
try:
    ft_cyc_lim = {}

    for i in range(0, len(b)):
        for j in range(0, len(f)):
            if f[j] > b[i] and f[j] < b[i+1]:
                if f[j+1]<b[i+1]:
                    print(b[i],f[j+1])

                    cyc_start = b[i]
                    cyc_end = f[j+1]

                    ft_cyc_lim.setdefault(cyc_start,cyc_end)

except IndexError:
    print('\nDone')
#------------------------------------------------------------
# Out:
# done
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in sign
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sign
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sign
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in less
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in sign
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sign
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in greater
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in sign
#   from ipykernel import kernelapp as app
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in less
#   from ipykernel import kernelapp as app

# %%
# This code will use the index range (or limits) to create a list of values: feedtime range, cake wash time range,
# then selects the max value as the parameter value for that range

keyslist = list(ft_cyc_lim.keys()) #creates a list of the ft_cyc_lim keys so that we can iterate later

#For loop Dictionary names 

A_Filt_MaxList= list()
A_CWP_MaxList= list()
A_MANFP_MaxList= list()
A_CWSH1_MaxList= list()
A_CWSH2_MaxList= list()
A_Press1_MaxList= list()
A_Press2_MaxList= list()
A_PU26A_OP_MaxList= list()
A_PU27A_OP_MaxList= list()
A_106PU26A_CUR_MaxList= list()
A_106PU27A_CUR_MaxList= list()

A_Filt_MaxList[:] = []
A_CWP_MaxList[:] = []
A_MANFP_MaxList[:] = []
A_CWSH1_MaxList[:] = []
A_CWSH2_MaxList[:] = []
A_Press1_MaxList[:] = []
A_Press2_MaxList[:] = []
A_PU26A_OP_MaxList[:] = []
A_PU27A_OP_MaxList[:] = []
A_106PU26A_CUR_MaxList[:] = []
A_106PU27A_CUR_MaxList[:] = []    


try:         
#for loop 1-------------------------------------------------------------------
    for i in range(0, len(keyslist)):

        A_Pair_Filt_List = list()
        A_Pair_Filt_List[:] = []
        A_feedt_Val_List = list()
        A_feedt_Val_List[:] = []
        A_feedt_index_List = list()
        A_feedt_index_List[:] = []
        
        
        A_Pair_CWP_List = list()
        A_CWP_val_List= list()
        A_CWP_index_List= list()
        
        A_Pair_CWP_List[:] = []
        A_CWP_val_List[:] = []
        A_CWP_index_List[:] = []
        
        A_Pair_MANFP_List =list() 
        A_MANFP_val_List=list() 
        A_MANFP_index_List=list() 
        
        A_Pair_MANFP_List[:] = []
        A_MANFP_val_List[:] = []
        A_MANFP_index_List[:] = []
        
        A_Pair_CWSH1_List=list() 
        A_t_CWSH1_val_List=list() 
        A_t_CWSH1_index_List=list() 
        
        A_Pair_CWSH1_List[:] = []
        A_t_CWSH1_val_List[:] = []
        A_t_CWSH1_index_List[:] = []
        
        A_Pair_CWSH2_List=list() 
        A_t_CWSH2_val_List=list() 
        A_t_CWSH2_index_List=list() 
        
        A_Pair_CWSH2_List[:] = []
        A_t_CWSH2_val_List[:] = []
        A_t_CWSH2_index_List[:] = []
        
        A_Pair_Press1_List=list()
        A_t_Press1_val_List=list() 
        A_t_Press1_index_List=list() 
        
        A_Pair_Press1_List[:] = []
        A_t_Press1_val_List[:] = []
        A_t_Press1_index_List[:] = []
        
        A_Pair_Press2_List=list() 
        A_t_Press2_val_List=list() 
        A_t_Press2_index_List=list() 
        
        A_Pair_Press2_List[:] = []
        A_t_Press2_val_List[:] = []
        A_t_Press2_index_List[:] = []
        
        A_Pair_PU26A_OP_List=list() 
        A_t_PU26A_OP_val_List=list() 
        A_t_PU26A_OP_index_List=list() 
                              
        A_Pair_PU26A_OP_List[:] = []
        A_t_PU26A_OP_val_List[:] = []
        A_t_PU26A_OP_index_List[:] = []
        
        A_Pair_PU27A_OP_List=list() 
        A_t_PU27A_OP_val_List=list() 
        A_t_PU27A_OP_index_List=list() 
        
        A_Pair_PU27A_OP_List[:] = []
        A_t_PU27A_OP_val_List[:] = []
        A_t_PU27A_OP_index_List[:] = []
        
        A_Pair_106PU26A_CUR_List=list() 
        A_t_106PU26A_CUR_val_List=list() 
        A_t_106PU26A_CUR_index_List=list() 
        
        A_Pair_106PU26A_CUR_List[:] = []
        A_t_106PU26A_CUR_val_List[:] = []
        A_t_106PU26A_CUR_index_List[:] = []
        
        A_Pair_106PU27A_CUR_List=list() 
        A_t_106PU27A_CUR_val_List=list() 
        A_t_106PU27A_CUR_index_List=list() 
        
        A_Pair_106PU27A_CUR_List[:] = []
        A_t_106PU27A_CUR_val_List[:] = []
        A_t_106PU27A_CUR_index_List[:] = []
            
#for loop 2-------------------------------------------------------------------        
        for j in range(keyslist[i], ft_cyc_lim[keyslist[i]]):               
            
            #Gets filtration time of the cycle
            A_feedt = df_comb['A_t_FEED'][j] #contains the actual cake washing pressure value          
            A_feedt_index_List.append(df_comb.index[j]) # stores the feedtime index into a list for use as key in the next steps 
            A_feedt_Val_List.append(A_feedt)
                  
            #Gets A CakeWashing Pressure of the cycle
            A_CWP = df_comb['106FT02A_CWP'][j] #contains the actual cake washing pressure value          
            A_CWP_index_List.append(df_comb.index[j]) # stores the feedtime index into a list for use as key in the next steps 
            A_CWP_val_List.append(A_CWP)              
            
            #Gets A manifold pressure of the cycle
            A_MANFP = df_comb['106FT02A_MANFP'][j] #contains the actual manifold pressure value          
            A_MANFP_index_List.append(df_comb.index[j]) # stores the manifold pressure index into a list for use as key in the next steps 
            A_MANFP_val_List.append(A_MANFP)
                                     
            #Gets A cakewash1 Time of the cycle
            A_t_CWSH1 = df_comb['A_t_CWSH1'][j] #contains the actual cake wash time value          
            A_t_CWSH1_index_List.append(df_comb.index[j]) # stores the cake wash time index into a list for use as key in the next steps 
            A_t_CWSH1_val_List.append(A_t_CWSH1)
                                     
            #Gets A cakewash2 Time of the cycle
            A_t_CWSH2 = df_comb['A_t_CWSH2'][j] #contains the actual cake wash2 time value                     
            A_t_CWSH2_index_List.append(df_comb.index[j]) # stores the cake wash2 time index into a list for use as key in the next steps 
            A_t_CWSH2_val_List.append(A_t_CWSH2)          
                                                 
            #Gets A Press1 Time of the cycle
            A_t_Press1 = df_comb['A_t_PRESS1'][j] #contains the actual Press1 time value          
            A_t_Press1_index_List.append(df_comb.index[j]) # stores the Press1 time index into a list for use as key in the next steps 
            A_t_Press1_val_List.append(A_t_Press1)
                        
            #Gets A Press2 Time of the cycle
            A_t_Press2 = df_comb['A_t_PRESS2'][j] #contains the actual Press2 Time time value          
            A_t_Press2_index_List.append(df_comb.index[j]) # stores the Press2 Time index into a list for use as key in the next steps  
            A_t_Press2_val_List.append(A_t_Press2)
                                    
            #Gets A max PU26A_OP PumpOP of the cycle
            A_t_PU26A_OP = df_comb['PU26A_OP'][j] #contains the actual max PU26A_OP PumpOP  
            A_t_PU26A_OP_index_List.append(df_comb.index[j]) # stores the max PU26A_OP PumpOP index into a list for use as key in the next steps 
            A_t_PU26A_OP_val_List.append(A_t_PU26A_OP)
            
            
            #Gets A max PU27A_OP of the cycle
            A_t_PU27A_OP = df_comb['PU27A_OP'][j] #contains the actual max PU27A_OP PumpOP  
            A_t_PU27A_OP_index_List.append(df_comb.index[j]) # stores the max PU27A_OP PumpOP index into a list for use as key in the next steps 
            A_t_PU27A_OP_val_List.append(A_t_PU27A_OP)
            
            
            #Gets A max 106PU26A_CUR of the cycle
            A_t_106PU26A_CUR = df_comb['106PU26A_CUR'][j] #contains the actual max PU26A_CUR  
            A_t_106PU26A_CUR_index_List.append(df_comb.index[j]) # stores the max PU26A_CUR index into a list for use as key in the next steps 
            A_t_106PU26A_CUR_val_List.append(A_t_106PU26A_CUR) 
            
       
            #Gets A max 106PU27A_CUR of the cycle
            A_t_106PU27A_CUR = df_comb['106PU27A_CUR'][j] #contains the actual max PU27A_CUR PumpOP  
            A_t_106PU27A_CUR_index_List.append(df_comb.index[j]) # stores the max PU27A_CUR index into a list for use as key in the next steps 
            A_t_106PU27A_CUR_val_List.append(A_t_106PU27A_CUR) 
         
            #Get the N2 dry value directly from the end of the N2 cycle
        
        #----End of 2nd for loop-------------------------------------------------
    
                     
        #A_feedtime
        #print(max(A_feedt_index_List))
        #A_maxfeedList.append(max(A_feedt_index_List)) #store feedtime index data into maxfeedList
        #A_feedT_Maxdict.setdefault(max(A_feedt_index_List),A_feedT_dict[max(A_feedt_index_List)]) # store the feed Time for each cycle in feedT_dict. Use maxfeedList as the keys
        
        A_Pair_Filt_List = list(zip(A_feedt_Val_List, A_feedt_index_List[0:]))
        A_Filt_MaxList.append(sorted(A_Pair_Filt_List)[-1])
        
        A_Pair_CWP_List = list(zip(A_CWP_val_List, A_CWP_index_List[0:]))
        A_CWP_MaxList.append(sorted(A_Pair_CWP_List)[-1])
           
        #
        A_Pair_MANFP_List = list(zip(A_MANFP_val_List, A_MANFP_index_List[0:]))
        A_MANFP_MaxList.append(sorted(A_Pair_MANFP_List)[-1])
        
        #
        A_Pair_CWSH1_List = list(zip(A_t_CWSH1_val_List, A_t_CWSH1_index_List[0:]))
        A_CWSH1_MaxList.append(sorted(A_Pair_CWSH1_List)[-1])
        
        #
        A_Pair_CWSH2_List = list(zip(A_t_CWSH2_val_List, A_t_CWSH2_index_List[0:]))
        A_CWSH2_MaxList.append(sorted(A_Pair_CWSH2_List)[-1])
                        
        A_Pair_Press1_List = list(zip(A_t_Press1_val_List, A_t_Press1_index_List[0:]))
        A_Press1_MaxList.append(sorted(A_Pair_Press1_List)[-1])
        
        A_Pair_Press2_List = list(zip(A_t_Press2_val_List, A_t_Press2_index_List[0:]))
        A_Press2_MaxList.append(sorted(A_Pair_Press2_List)[-1])
        
        A_Pair_PU26A_OP_List = list(zip(A_t_PU26A_OP_val_List, A_t_PU26A_OP_index_List[0:]))
        A_PU26A_OP_MaxList.append(sorted(A_Pair_PU26A_OP_List)[-1])
      
        A_Pair_PU27A_OP_List = list(zip(A_t_PU27A_OP_val_List, A_t_PU27A_OP_index_List[0:]))
        A_PU27A_OP_MaxList.append(sorted(A_Pair_PU27A_OP_List)[-1])
     
        A_Pair_106PU26A_CUR_List = list(zip(A_t_106PU26A_CUR_val_List, A_t_106PU26A_CUR_index_List[0:]))
        A_106PU26A_CUR_MaxList.append(sorted(A_Pair_106PU26A_CUR_List)[-1])
        
        A_Pair_106PU27A_CUR_List = list(zip(A_t_106PU27A_CUR_val_List, A_t_106PU27A_CUR_index_List[0:]))
        A_106PU27A_CUR_MaxList.append(sorted(A_Pair_106PU27A_CUR_List)[-1])
     
        
#this part is for correction-----------------------------------------------------       
        
        
              
        #'A_N2_Dry:',df_comb['A_t_DRY'][ft_cyc_lim[keyslist[i]]] #Get the N2 dry value directly from the end of the N2 cycle
#----End of for correction part--------------------------------------------------------------

          
except:
    pass
    
print('Done')
# Out:
# Done

# %%
#this code creates a new DF from the A_CWP_Maxlist

df_A_CWP = pd.DataFrame(A_CWP_MaxList)
df_A_CWP.columns = ['A_CWP', 'DATETIME']
df_A_CWP.set_index('DATETIME', inplace=True)

#this code replaces the 'No Good Data' from 106PU26A_CUR column
for x in range(0, len(df_comb['106PU26A_CUR'])):
    if df_comb['106PU26A_CUR'][x] =='[-11059] No Good Data For Calculation':
            df_comb['106PU26A_CUR'][x] = 0
           
            
#this code turns the maxlist to a dataframe then joins them into a one dataframe

df_A_Filt = pd.DataFrame(A_Filt_MaxList)
df_A_Filt.columns = ['A_Filt', 'DATETIME']
df_A_Filt.set_index('DATETIME', inplace=True)

df_A_CWP = pd.DataFrame(A_CWP_MaxList)
df_A_CWP.columns = ['A_CWP', 'DATETIME']
df_A_CWP.set_index('DATETIME', inplace=True)

df_A_MANFP = pd.DataFrame(A_MANFP_MaxList)
df_A_MANFP.columns = ['A_MANFP', 'DATETIME']
df_A_MANFP.set_index('DATETIME', inplace=True)

df_A_CWSH1 = pd.DataFrame(A_CWSH1_MaxList)
df_A_CWSH1.columns = ['A_CWSH1', 'DATETIME']
df_A_CWSH1.set_index('DATETIME', inplace=True)

df_A_CWSH2 = pd.DataFrame(A_CWSH2_MaxList)
df_A_CWSH2.columns = ['A_CWSH2', 'DATETIME']
df_A_CWSH2.set_index('DATETIME', inplace=True)

df_A_Press1 = pd.DataFrame(A_Press1_MaxList)
df_A_Press1.columns = ['A_Press1', 'DATETIME']
df_A_Press1.set_index('DATETIME', inplace=True)

df_A_Press2 = pd.DataFrame(A_Press2_MaxList)
df_A_Press2.columns = ['A_Press2', 'DATETIME']
df_A_Press2.set_index('DATETIME', inplace=True)

df_A_PU26A_OP = pd.DataFrame(A_PU26A_OP_MaxList)
df_A_PU26A_OP.columns = ['A_PU26A_OP', 'DATETIME']
df_A_PU26A_OP.set_index('DATETIME', inplace=True)

df_A_PU27A_OP = pd.DataFrame(A_PU27A_OP_MaxList)
df_A_PU27A_OP.columns = ['A_PU27A_OP', 'DATETIME']
df_A_PU27A_OP.set_index('DATETIME', inplace=True)

df_A_106PU26A_CUR = pd.DataFrame(A_106PU26A_CUR_MaxList)
df_A_106PU26A_CUR.columns = ['A_106PU26A_CUR', 'DATETIME']
df_A_106PU26A_CUR.set_index('DATETIME', inplace=True)

df_A_106PU27A_CUR = pd.DataFrame(A_106PU27A_CUR_MaxList)
df_A_106PU27A_CUR.columns = ['A_106PU27A_CUR', 'DATETIME']
df_A_106PU27A_CUR.set_index('DATETIME', inplace=True)

# %%
dfn = df_A_106PU27A_CUR.join(df_A_106PU26A_CUR, how='outer')
dfn1 = df_A_PU27A_OP.join(df_A_PU26A_OP, how='outer')
dfn2 = df_A_Press2.join(df_A_Press1, how='outer')
dfn3 = df_A_CWSH2.join(df_A_CWSH1, how='outer')
dfn4 = df_A_MANFP.join(df_A_CWP, how='outer')

dfn5 = df_A_Filt.join(dfn, how='outer')
dfn6 = dfn1.join(dfn2, how='outer')
dfn7 = dfn3.join(dfn4, how='outer')

dfn8 = dfn5.join(dfn6, how='outer')
dfn9 = dfn7.join(dfn8, how='outer')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3597: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects
#   join_index = self.union(other)

# %%
dfn9.to_excel(r'C:\Users\v.t.flores\Documents\201911Data_Mg_Inv_20200113trial.xlsx')

# %%
print(df_comb.index[keyslist[0]],'-',df_comb.index[ft_cyc_lim[keyslist[0]]])
# Out:
# 2019-11-01 00:11:00 - 2019-11-01 00:34:00

# %%
dflist = []
dflist.append((str(df_comb.index[keyslist[0]])+" to "+str(df_comb.index[ft_cyc_lim[keyslist[0]]])))

# %%
type(dflist[0])
# Out:
# str

# %%
dflist
# Out:
# ['2019-11-01 00:11:00 to 2019-11-01 00:34:00']

# %%
A_106PU26A_CUR_MaxList
# Out:
# [(49.02912139892578, Timestamp('2019-11-01 00:12:00')),
#  (48.851280212402344, Timestamp('2019-11-01 00:36:00')),
#  (48.57768249511719, Timestamp('2019-11-01 01:02:00')),
#  (48.7076416015625, Timestamp('2019-11-01 01:27:00')),
#  (48.82392120361328, Timestamp('2019-11-01 01:53:00')),
#  (48.37932205200195, Timestamp('2019-11-01 02:19:00')),
#  (49.637882232666016, Timestamp('2019-11-01 02:44:00')),
#  (49.070159912109375, Timestamp('2019-11-01 03:08:00')),
#  (48.263038635253906, Timestamp('2019-11-01 03:36:00')),
#  (49.24800109863281, Timestamp('2019-11-01 03:59:00')),
#  (47.83211898803711, Timestamp('2019-11-01 04:26:00')),
#  (48.919677734375, Timestamp('2019-11-01 05:19:00')),
#  (49.111202239990234, Timestamp('2019-11-01 05:43:00')),
#  (49.425846099853516, Timestamp('2019-11-01 06:06:00')),
#  (48.83076095581055, Timestamp('2019-11-01 06:32:00')),
#  (48.56399917602539, Timestamp('2019-11-01 06:57:00')),
#  (48.550323486328125, Timestamp('2019-11-01 07:23:00')),
#  (50.11668014526367, Timestamp('2019-11-01 07:49:00')),
#  (49.64472198486328, Timestamp('2019-11-01 08:15:00')),
#  (49.88412094116211, Timestamp('2019-11-01 15:57:00')),
#  (48.8991584777832, Timestamp('2019-11-01 16:23:00')),
#  (48.57084655761719, Timestamp('2019-11-01 16:52:00')),
#  (50.1645622253418, Timestamp('2019-11-01 17:15:00')),
#  (49.179603576660156, Timestamp('2019-11-01 17:40:00')),
#  (50.622840881347656, Timestamp('2019-11-01 18:05:00')),
#  (49.41899871826172, Timestamp('2019-11-01 18:31:00')),
#  (48.9333610534668, Timestamp('2019-11-01 18:57:00')),
#  (50.05512237548828, Timestamp('2019-11-01 19:23:00')),
#  (49.26852035522461, Timestamp('2019-11-01 19:50:00')),
#  (50.7733268737793, Timestamp('2019-11-01 20:14:00')),
#  (48.953880310058594, Timestamp('2019-11-01 20:40:00')),
#  (49.487403869628906, Timestamp('2019-11-01 21:06:00')),
#  (49.20696258544922, Timestamp('2019-11-01 21:31:00')),
#  (52.674842834472656, Timestamp('2019-11-01 21:56:00')),
#  (49.3232421875, Timestamp('2019-11-01 22:21:00')),
#  (49.3095588684082, Timestamp('2019-11-01 22:45:00')),
#  (49.71311950683594, Timestamp('2019-11-01 23:10:00')),
#  (50.43815994262695, Timestamp('2019-11-01 23:34:00')),
#  (49.04963684082031, Timestamp('2019-11-01 23:59:00')),
#  (49.45320129394531, Timestamp('2019-11-02 00:23:00')),
#  (50.39027786254883, Timestamp('2019-11-02 00:46:00')),
#  (49.43952178955078, Timestamp('2019-11-02 01:11:00')),
#  (49.50791931152344, Timestamp('2019-11-02 01:35:00')),
#  (49.391639709472656, Timestamp('2019-11-02 02:00:00')),
#  (48.97439956665039, Timestamp('2019-11-02 02:25:00')),
#  (49.740482330322266, Timestamp('2019-11-02 02:50:00')),
#  (48.7076416015625, Timestamp('2019-11-02 03:15:00')),
#  (48.776039123535156, Timestamp('2019-11-02 03:40:00')),
#  (50.458675384521484, Timestamp('2019-11-02 04:05:00')),
#  (48.07151794433594, Timestamp('2019-11-02 04:31:00')),
#  (47.85264205932617, Timestamp('2019-11-02 04:56:00')),
#  (48.085205078125, Timestamp('2019-11-02 05:22:00')),
#  (47.483280181884766, Timestamp('2019-11-02 05:47:00')),
#  (48.05784225463867, Timestamp('2019-11-02 06:12:00')),
#  (47.60639953613281, Timestamp('2019-11-02 06:37:00')),
#  (48.769203186035156, Timestamp('2019-11-02 07:23:00')),
#  (48.871795654296875, Timestamp('2019-11-02 07:48:00')),
#  (51.71039962768555, Timestamp('2019-11-02 08:12:00')),
#  (48.393001556396484, Timestamp('2019-11-02 08:38:00')),
#  (48.48191833496094, Timestamp('2019-11-02 09:02:00')),
#  (51.47100067138672, Timestamp('2019-11-02 09:27:00')),
#  (48.605037689208984, Timestamp('2019-11-02 09:51:00')),
#  (47.79108428955078, Timestamp('2019-11-02 10:16:00')),
#  (49.432682037353516, Timestamp('2019-11-02 10:42:00')),
#  (48.68027877807617, Timestamp('2019-11-02 11:07:00')),
#  (51.375240325927734, Timestamp('2019-11-02 11:31:00')),
#  (49.70627975463867, Timestamp('2019-11-02 11:57:00')),
#  (48.598201751708984, Timestamp('2019-11-02 12:22:00')),
#  (48.810237884521484, Timestamp('2019-11-02 12:48:00')),
#  (48.1057243347168, Timestamp('2019-11-02 13:14:00')),
#  (48.74184036254883, Timestamp('2019-11-02 14:22:00')),
#  (48.557159423828125, Timestamp('2019-11-02 14:47:00')),
#  (47.9005241394043, Timestamp('2019-11-02 15:13:00')),
#  (48.53664016723633, Timestamp('2019-11-02 15:36:00')),
#  (48.38615798950195, Timestamp('2019-11-02 16:01:00')),
#  (49.41215896606445, Timestamp('2019-11-02 16:26:00')),
#  (48.61872100830078, Timestamp('2019-11-02 16:51:00')),
#  (50.06196212768555, Timestamp('2019-11-02 17:16:00')),
#  (49.056480407714844, Timestamp('2019-11-02 17:42:00')),
#  (48.83760070800781, Timestamp('2019-11-02 18:05:00')),
#  (49.9593620300293, Timestamp('2019-11-02 18:30:00')),
#  (49.1385612487793, Timestamp('2019-11-02 18:55:00')),
#  (49.82939910888672, Timestamp('2019-11-02 19:19:00')),
#  (48.78972244262695, Timestamp('2019-11-02 19:45:00')),
#  (49.063323974609375, Timestamp('2019-11-02 20:10:00')),
#  (49.1043586730957, Timestamp('2019-11-02 20:35:00')),
#  (48.20832443237305, Timestamp('2019-11-02 21:02:00')),
#  (48.42720031738281, Timestamp('2019-11-02 21:27:00')),
#  (50.3697624206543, Timestamp('2019-11-02 21:51:00')),
#  (48.310916900634766, Timestamp('2019-11-02 22:17:00')),
#  (50.72544479370117, Timestamp('2019-11-02 23:08:00')),
#  (50.26032257080078, Timestamp('2019-11-02 23:33:00')),
#  (49.65155792236328, Timestamp('2019-11-02 23:58:00')),
#  (49.20696258544922, Timestamp('2019-11-03 00:24:00')),
#  (48.960723876953125, Timestamp('2019-11-03 00:48:00')),
#  (50.79384231567383, Timestamp('2019-11-03 01:13:00')),
#  (48.83760070800781, Timestamp('2019-11-03 01:40:00')),
#  (49.44636154174805, Timestamp('2019-11-03 02:05:00')),
#  (49.71311950683594, Timestamp('2019-11-03 02:31:00')),
#  (52.55172348022461, Timestamp('2019-11-03 02:56:00')),
#  (48.06467819213867, Timestamp('2019-11-03 03:25:00')),
#  (49.67208480834961, Timestamp('2019-11-03 03:49:00')),
#  (49.993560791015625, Timestamp('2019-11-03 05:04:00')),
#  (49.391639709472656, Timestamp('2019-11-03 05:29:00')),
#  (49.391639709472656, Timestamp('2019-11-03 05:55:00')),
#  (50.91012191772461, Timestamp('2019-11-03 06:19:00')),
#  (50.212440490722656, Timestamp('2019-11-03 06:44:00')),
#  (49.50791931152344, Timestamp('2019-11-03 07:10:00')),
#  (49.3027229309082, Timestamp('2019-11-03 07:36:00')),
#  (49.61736297607422, Timestamp('2019-11-03 08:00:00')),
#  (41.204158782958984, Timestamp('2019-11-03 08:26:00')),
#  (50.52708435058594, Timestamp('2019-11-03 08:54:00')),
#  (49.48055648803711, Timestamp('2019-11-03 09:21:00')),
#  (48.97439956665039, Timestamp('2019-11-03 09:50:00')),
#  (49.289039611816406, Timestamp('2019-11-03 10:14:00')),
#  (49.9388427734375, Timestamp('2019-11-03 10:56:00')),
#  (50.308204650878906, Timestamp('2019-11-03 11:21:00')),
#  (50.034603118896484, Timestamp('2019-11-03 11:46:00')),
#  (50.280845642089844, Timestamp('2019-11-03 12:10:00')),
#  (50.875919342041016, Timestamp('2019-11-03 12:35:00')),
#  (52.07976150512695, Timestamp('2019-11-03 13:00:00')),
#  (50.5749626159668, Timestamp('2019-11-03 13:25:00')),
#  (50.609161376953125, Timestamp('2019-11-03 13:50:00')),
#  (51.04692077636719, Timestamp('2019-11-03 14:15:00')),
#  (53.447757720947266, Timestamp('2019-11-03 14:39:00')),
#  (53.61875915527344, Timestamp('2019-11-03 15:04:00')),
#  (53.276763916015625, Timestamp('2019-11-03 15:29:00')),
#  (50.356082916259766, Timestamp('2019-11-03 15:54:00')),
#  (51.68303680419922, Timestamp('2019-11-03 16:19:00')),
#  (50.12351989746094, Timestamp('2019-11-03 16:46:00')),
#  (49.952518463134766, Timestamp('2019-11-03 17:10:00')),
#  (52.1823616027832, Timestamp('2019-11-03 17:33:00')),
#  (51.929283142089844, Timestamp('2019-11-03 17:58:00')),
#  (49.795204162597656, Timestamp('2019-11-03 18:24:00')),
#  (50.513397216796875, Timestamp('2019-11-03 18:48:00')),
#  (50.903282165527344, Timestamp('2019-11-03 19:13:00')),
#  (50.47236251831055, Timestamp('2019-11-03 19:39:00')),
#  (51.949798583984375, Timestamp('2019-11-03 20:03:00')),
#  (50.38344192504883, Timestamp('2019-11-03 20:29:00')),
#  (50.38344192504883, Timestamp('2019-11-03 20:55:00')),
#  (50.32188034057617, Timestamp('2019-11-03 21:20:00')),
#  (50.451839447021484, Timestamp('2019-11-03 21:45:00')),
#  (50.191917419433594, Timestamp('2019-11-03 22:11:00')),
#  (50.451839447021484, Timestamp('2019-11-03 22:36:00')),
#  (50.68439865112305, Timestamp('2019-11-03 23:02:00')),
#  (50.144039154052734, Timestamp('2019-11-03 23:28:00')),
#  (49.76100158691406, Timestamp('2019-11-03 23:54:00')),
#  (50.01408386230469, Timestamp('2019-11-04 00:19:00')),
#  (51.5667610168457, Timestamp('2019-11-04 00:44:00')),
#  (50.37660217285156, Timestamp('2019-11-04 01:11:00')),
#  (50.02775955200195, Timestamp('2019-11-04 01:35:00')),
#  (49.993560791015625, Timestamp('2019-11-04 02:01:00')),
#  (49.81572341918945, Timestamp('2019-11-04 02:26:00')),
#  (51.012725830078125, Timestamp('2019-11-04 02:51:00')),
#  (49.43952178955078, Timestamp('2019-11-04 03:17:00')),
#  (49.48055648803711, Timestamp('2019-11-04 03:43:00')),
#  (55.56132507324219, Timestamp('2019-11-04 04:07:00')),
#  (52.038719177246094, Timestamp('2019-11-04 04:33:00')),
#  (49.870445251464844, Timestamp('2019-11-04 04:58:00')),
#  (49.877281188964844, Timestamp('2019-11-04 05:24:00')),
#  (50.1303596496582, Timestamp('2019-11-04 05:49:00')),
#  (49.849918365478516, Timestamp('2019-11-04 06:14:00')),
#  (50.09615707397461, Timestamp('2019-11-04 06:42:00')),
#  (50.15087890625, Timestamp('2019-11-04 07:07:00')),
#  (49.67892074584961, Timestamp('2019-11-04 07:34:00')),
#  (49.9251594543457, Timestamp('2019-11-04 08:01:00')),
#  (50.93748092651367, Timestamp('2019-11-04 08:27:00')),
#  (49.733642578125, Timestamp('2019-11-04 08:55:00')),
#  (49.890960693359375, Timestamp('2019-11-04 09:21:00')),
#  (50.07563781738281, Timestamp('2019-11-04 09:48:00')),
#  (51.730918884277344, Timestamp('2019-11-04 10:14:00')),
#  (50.417640686035156, Timestamp('2019-11-04 10:41:00')),
#  (51.785640716552734, Timestamp('2019-11-04 11:08:00')),
#  (51.53255844116211, Timestamp('2019-11-04 11:34:00')),
#  (50.79384231567383, Timestamp('2019-11-04 12:01:00')),
#  (51.35472106933594, Timestamp('2019-11-04 12:28:00')),
#  (49.66523742675781, Timestamp('2019-11-04 12:55:00')),
#  (49.03596115112305, Timestamp('2019-11-04 13:22:00')),
#  (49.316402435302734, Timestamp('2019-11-04 14:23:00')),
#  (51.10163879394531, Timestamp('2019-11-04 14:51:00')),
#  (49.40532302856445, Timestamp('2019-11-04 15:21:00')),
#  (55.766517639160156, Timestamp('2019-11-04 15:46:00')),
#  (49.55580139160156, Timestamp('2019-11-04 16:14:00')),
#  (49.9593620300293, Timestamp('2019-11-04 16:40:00')),
#  (49.21379852294922, Timestamp('2019-11-04 17:08:00')),
#  (49.3095588684082, Timestamp('2019-11-04 17:36:00')),
#  (50.09615707397461, Timestamp('2019-11-04 18:05:00')),
#  (49.5284423828125, Timestamp('2019-11-04 18:33:00')),
#  (50.26715850830078, Timestamp('2019-11-04 19:01:00')),
#  (49.19328308105469, Timestamp('2019-11-04 19:29:00')),
#  (49.261680603027344, Timestamp('2019-11-04 19:58:00')),
#  (49.624202728271484, Timestamp('2019-11-04 20:26:00')),
#  (49.04963684082031, Timestamp('2019-11-04 20:56:00')),
#  (51.5872802734375, Timestamp('2019-11-04 21:24:00')),
#  (48.598201751708984, Timestamp('2019-11-04 21:54:00')),
#  (49.26852035522461, Timestamp('2019-11-04 22:21:00')),
#  (48.37248229980469, Timestamp('2019-11-04 22:50:00')),
#  (48.7076416015625, Timestamp('2019-11-04 23:16:00')),
#  (49.1385612487793, Timestamp('2019-11-04 23:44:00')),
#  (51.785640716552734, Timestamp('2019-11-05 00:12:00')),
#  (49.3095588684082, Timestamp('2019-11-05 00:41:00')),
#  (47.0865592956543, Timestamp('2019-11-05 01:10:00')),
#  (46.74456024169922, Timestamp('2019-11-05 01:38:00')),
#  (46.60091781616211, Timestamp('2019-11-05 02:06:00')),
#  (51.211082458496094, Timestamp('2019-11-05 02:47:00')),
#  (47.97576141357422, Timestamp('2019-11-05 03:14:00')),
#  (47.23704147338867, Timestamp('2019-11-05 03:41:00')),
#  (46.806121826171875, Timestamp('2019-11-05 04:09:00')),
#  (49.795204162597656, Timestamp('2019-11-05 04:45:00')),
#  (47.674800872802734, Timestamp('2019-11-05 05:28:00')),
#  (47.49696350097656, Timestamp('2019-11-05 05:53:00')),
#  (47.0592041015625, Timestamp('2019-11-05 06:20:00')),
#  (48.26988220214844, Timestamp('2019-11-05 07:13:00')),
#  (48.81708526611328, Timestamp('2019-11-05 07:38:00')),
#  (47.92103958129883, Timestamp('2019-11-05 08:04:00')),
#  (47.65428161621094, Timestamp('2019-11-05 08:30:00')),
#  (47.421722412109375, Timestamp('2019-11-05 08:58:00')),
#  (47.09339904785156, Timestamp('2019-11-05 09:23:00')),
#  (48.399845123291016, Timestamp('2019-11-05 09:50:00')),
#  (51.31367492675781, Timestamp('2019-11-05 10:16:00')),
#  (48.22200012207031, Timestamp('2019-11-05 10:42:00')),
#  (48.201480865478516, Timestamp('2019-11-05 11:07:00')),
#  (48.666603088378906, Timestamp('2019-11-05 11:34:00')),
#  (47.40119934082031, Timestamp('2019-11-05 12:01:00')),
#  (48.051002502441406, Timestamp('2019-11-05 12:28:00')),
#  (47.0797233581543, Timestamp('2019-11-05 12:55:00')),
#  (47.77055740356445, Timestamp('2019-11-05 13:22:00')),
#  (48.38615798950195, Timestamp('2019-11-05 14:28:00')),
#  (47.65428161621094, Timestamp('2019-11-05 14:55:00')),
#  (47.818443298339844, Timestamp('2019-11-05 16:10:00')),
#  (47.517478942871094, Timestamp('2019-11-05 16:37:00')),
#  (47.29860305786133, Timestamp('2019-11-05 17:05:00')),
#  (47.0797233581543, Timestamp('2019-11-05 17:34:00')),
#  (47.03867721557617, Timestamp('2019-11-05 17:59:00')),
#  (46.812965393066406, Timestamp('2019-11-05 18:28:00')),
#  (48.00312042236328, Timestamp('2019-11-05 19:28:00')),
#  (47.6953239440918, Timestamp('2019-11-05 19:53:00')),
#  (47.62691879272461, Timestamp('2019-11-05 20:20:00')),
#  (47.0797233581543, Timestamp('2019-11-05 20:47:00')),
#  (46.997642517089844, Timestamp('2019-11-05 21:16:00')),
#  (51.96348190307617, Timestamp('2019-11-05 21:56:00')),
#  (49.979881286621094, Timestamp('2019-11-05 22:39:00')),
#  (47.681640625, Timestamp('2019-11-05 23:07:00')),
#  (48.14676284790039, Timestamp('2019-11-05 23:33:00')),
#  (50.69123840332031, Timestamp('2019-11-06 00:11:00')),
#  (48.023643493652344, Timestamp('2019-11-06 00:56:00')),
#  (48.03048324584961, Timestamp('2019-11-06 01:24:00')),
#  (47.305442810058594, Timestamp('2019-11-06 01:52:00')),
#  (47.40119934082031, Timestamp('2019-11-06 02:19:00')),
#  (47.81159973144531, Timestamp('2019-11-06 02:52:00')),
#  (47.4696044921875, Timestamp('2019-11-06 03:20:00')),
#  (47.729522705078125, Timestamp('2019-11-06 03:45:00')),
#  (47.97576141357422, Timestamp('2019-11-06 04:12:00')),
#  (51.86772537231445, Timestamp('2019-11-06 04:38:00')),
#  (48.700801849365234, Timestamp('2019-11-06 05:04:00')),
#  (48.16728210449219, Timestamp('2019-11-06 05:30:00')),
#  (47.729522705078125, Timestamp('2019-11-06 05:56:00')),
#  (47.23704147338867, Timestamp('2019-11-06 06:22:00')),
#  (49.43952178955078, Timestamp('2019-11-06 06:49:00')),
#  (48.557159423828125, Timestamp('2019-11-06 07:44:00')),
#  (48.20832443237305, Timestamp('2019-11-06 15:43:00')),
#  (47.722679138183594, Timestamp('2019-11-06 16:13:00')),
#  (47.03184127807617, Timestamp('2019-11-06 16:47:00')),
#  (46.922401428222656, Timestamp('2019-11-06 17:17:00')),
#  (48.454559326171875, Timestamp('2019-11-06 17:48:00')),
#  (48.41352081298828, Timestamp('2019-11-06 18:32:00')),
#  (47.982601165771484, Timestamp('2019-11-06 19:00:00')),
#  (47.784244537353516, Timestamp('2019-11-06 19:29:00')),
#  (47.45591735839844, Timestamp('2019-11-06 19:59:00')),
#  (47.29176330566406, Timestamp('2019-11-06 20:30:00')),
#  (47.18915939331055, Timestamp('2019-11-06 20:58:00')),
#  (48.26988220214844, Timestamp('2019-11-06 21:27:00')),
#  (47.0660400390625, Timestamp('2019-11-06 21:56:00')),
#  (47.14128112792969, Timestamp('2019-11-06 22:26:00')),
#  (49.5147590637207, Timestamp('2019-11-06 22:53:00')),
#  (48.2835578918457, Timestamp('2019-11-06 23:22:00')),
#  (47.667964935302734, Timestamp('2019-11-06 23:50:00')),
#  (47.750038146972656, Timestamp('2019-11-07 00:19:00')),
#  (48.263038635253906, Timestamp('2019-11-07 00:47:00')),
#  (47.83211898803711, Timestamp('2019-11-07 01:17:00')),
#  (48.263038635253906, Timestamp('2019-11-07 01:47:00')),
#  (47.585880279541016, Timestamp('2019-11-07 02:16:00')),
#  (47.92103958129883, Timestamp('2019-11-07 02:46:00')),
#  (47.44224166870117, Timestamp('2019-11-07 03:15:00')),
#  (51.5667610168457, Timestamp('2019-11-07 04:09:00')),
#  (49.44636154174805, Timestamp('2019-11-07 04:37:00')),
#  (48.64608383178711, Timestamp('2019-11-07 05:04:00')),
#  (47.91420364379883, Timestamp('2019-11-07 05:31:00')),
#  (48.67344284057617, Timestamp('2019-11-07 05:59:00')),
#  (48.1057243347168, Timestamp('2019-11-07 06:27:00')),
#  (47.0865592956543, Timestamp('2019-11-07 06:57:00')),
#  (46.587242126464844, Timestamp('2019-11-07 07:28:00')),
#  (47.572200775146484, Timestamp('2019-11-07 08:04:00')),
#  (47.7021598815918, Timestamp('2019-11-07 08:33:00')),
#  (47.284915924072266, Timestamp('2019-11-07 09:03:00')),
#  (46.183677673339844, Timestamp('2019-11-07 09:32:00')),
#  (48.755523681640625, Timestamp('2019-11-07 10:06:00')),
#  (46.293121337890625, Timestamp('2019-11-07 10:37:00')),
#  (47.0660400390625, Timestamp('2019-11-07 11:11:00')),
#  (46.819801330566406, Timestamp('2019-11-07 11:46:00')),
#  (47.14128112792969, Timestamp('2019-11-07 13:22:00')),
#  (45.54755783081055, Timestamp('2019-11-07 13:59:00')),
#  (47.64744186401367, Timestamp('2019-11-07 17:31:00')),
#  (48.844444274902344, Timestamp('2019-11-07 17:54:00')),
#  (49.165916442871094, Timestamp('2019-11-07 18:17:00')),
#  (52.59275817871094, Timestamp('2019-11-07 18:40:00')),
#  (51.68303680419922, Timestamp('2019-11-07 19:03:00')),
#  (48.201480865478516, Timestamp('2019-11-07 19:28:00')),
#  (47.838966369628906, Timestamp('2019-11-07 19:54:00')),
#  (47.127601623535156, Timestamp('2019-11-07 20:21:00')),
#  (47.79108428955078, Timestamp('2019-11-07 21:30:00')),
#  (47.90736389160156, Timestamp('2019-11-07 21:59:00')),
#  (48.051002502441406, Timestamp('2019-11-07 23:01:00')),
#  (48.50244140625, Timestamp('2019-11-07 23:29:00')),
#  (47.476444244384766, Timestamp('2019-11-07 23:59:00')),
#  (47.75688171386719, Timestamp('2019-11-08 00:29:00')),
#  (46.78559875488281, Timestamp('2019-11-08 01:01:00')),
#  (47.51063919067383, Timestamp('2019-11-08 01:48:00')),
#  (48.393001556396484, Timestamp('2019-11-08 02:16:00')),
#  (48.1057243347168, Timestamp('2019-11-08 02:45:00')),
#  (48.81708526611328, Timestamp('2019-11-08 03:14:00')),
#  (47.15496063232422, Timestamp('2019-11-08 03:44:00')),
#  (46.970279693603516, Timestamp('2019-11-08 04:14:00')),
#  (47.14812088012695, Timestamp('2019-11-08 05:27:00')),
#  (47.640602111816406, Timestamp('2019-11-08 06:18:00')),
#  (47.59272384643555, Timestamp('2019-11-08 06:45:00')),
#  (50.73912048339844, Timestamp('2019-11-08 07:12:00')),
#  (47.49696350097656, Timestamp('2019-11-08 07:40:00')),
#  (48.201480865478516, Timestamp('2019-11-08 09:24:00')),
#  (51.1768798828125, Timestamp('2019-11-08 09:51:00')),
#  (48.1125602722168, Timestamp('2019-11-08 10:18:00')),
#  (47.305442810058594, Timestamp('2019-11-08 10:47:00')),
#  (47.92103958129883, Timestamp('2019-11-08 11:53:00')),
#  (47.62691879272461, Timestamp('2019-11-08 12:22:00')),
#  (47.62691879272461, Timestamp('2019-11-08 12:46:00')),
#  (50.17824172973633, Timestamp('2019-11-08 13:46:00')),
#  (48.21516036987305, Timestamp('2019-11-08 14:14:00')),
#  (48.098880767822266, Timestamp('2019-11-08 14:40:00')),
#  (48.97439956665039, Timestamp('2019-11-08 15:06:00')),
#  (47.934722900390625, Timestamp('2019-11-08 15:34:00')),
#  (46.99079895019531, Timestamp('2019-11-08 16:02:00')),
#  (48.56399917602539, Timestamp('2019-11-08 18:01:00')),
#  (47.8663215637207, Timestamp('2019-11-08 18:29:00')),
#  (49.740482330322266, Timestamp('2019-11-08 18:55:00')),
#  (48.21516036987305, Timestamp('2019-11-08 19:23:00')),
#  (47.92103958129883, Timestamp('2019-11-08 20:15:00')),
#  (47.80475997924805, Timestamp('2019-11-08 20:43:00')),
#  (48.235679626464844, Timestamp('2019-11-08 21:06:00')),
#  (47.23704147338867, Timestamp('2019-11-08 21:36:00')),
#  (47.85948181152344, Timestamp('2019-11-08 21:59:00')),
#  (47.03184127807617, Timestamp('2019-11-08 22:28:00')),
#  (48.509281158447266, Timestamp('2019-11-08 23:26:00')),
#  (49.00176239013672, Timestamp('2019-11-08 23:53:00')),
#  (51.443641662597656, Timestamp('2019-11-09 00:20:00')),
#  (48.37248229980469, Timestamp('2019-11-09 00:48:00')),
#  (48.7281608581543, Timestamp('2019-11-09 01:16:00')),
#  (48.139915466308594, Timestamp('2019-11-09 01:45:00')),
#  (48.01679611206055, Timestamp('2019-11-09 02:14:00')),
#  (47.62691879272461, Timestamp('2019-11-09 02:45:00')),
#  (47.34648132324219, Timestamp('2019-11-09 03:10:00')),
#  (48.8991584777832, Timestamp('2019-11-09 03:38:00')),
#  (50.67755889892578, Timestamp('2019-11-09 05:17:00')),
#  (47.750038146972656, Timestamp('2019-11-09 05:46:00')),
#  (47.476444244384766, Timestamp('2019-11-09 06:12:00')),
#  (47.674800872802734, Timestamp('2019-11-09 06:43:00')),
#  (48.03048324584961, Timestamp('2019-11-09 07:07:00')),
#  (50.32872009277344, Timestamp('2019-11-09 07:32:00')),
#  (47.09339904785156, Timestamp('2019-11-09 08:00:00')),
#  (47.81159973144531, Timestamp('2019-11-09 08:26:00')),
#  (47.8731575012207, Timestamp('2019-11-09 09:52:00')),
#  (47.79792022705078, Timestamp('2019-11-09 10:19:00')),
#  (46.792442321777344, Timestamp('2019-11-09 10:48:00')),
#  (48.906002044677734, Timestamp('2019-11-09 11:16:00')),
#  (47.91420364379883, Timestamp('2019-11-09 12:13:00')),
#  (48.406681060791016, Timestamp('2019-11-09 12:41:00')),
#  (47.50379943847656, Timestamp('2019-11-09 13:10:00')),
#  (48.919677734375, Timestamp('2019-11-09 13:40:00')),
#  (48.68027877807617, Timestamp('2019-11-09 15:19:00')),
#  (47.60639953613281, Timestamp('2019-11-09 15:49:00')),
#  (47.03867721557617, Timestamp('2019-11-09 16:21:00')),
#  (46.42308044433594, Timestamp('2019-11-09 16:51:00')),
#  (48.03048324584961, Timestamp('2019-11-09 17:38:00')),
#  (48.16728210449219, Timestamp('2019-11-09 18:06:00')),
#  (49.802040100097656, Timestamp('2019-11-09 18:33:00')),
#  (47.743202209472656, Timestamp('2019-11-09 19:26:00')),
#  (47.80475997924805, Timestamp('2019-11-09 19:52:00')),
#  (49.76784133911133, Timestamp('2019-11-09 20:19:00')),
#  (48.037322998046875, Timestamp('2019-11-09 21:37:00')),
#  (47.640602111816406, Timestamp('2019-11-09 22:05:00')),
#  (47.202842712402344, Timestamp('2019-11-09 22:33:00')),
#  (48.338279724121094, Timestamp('2019-11-09 23:25:00')),
#  (47.49696350097656, Timestamp('2019-11-09 23:55:00')),
#  (47.40119934082031, Timestamp('2019-11-10 00:25:00')),
#  (47.65428161621094, Timestamp('2019-11-10 00:54:00')),
#  (47.750038146972656, Timestamp('2019-11-10 01:21:00')),
#  (46.6556396484375, Timestamp('2019-11-10 01:49:00')),
#  (48.7281608581543, Timestamp('2019-11-10 02:17:00')),
#  (47.0865592956543, Timestamp('2019-11-10 03:42:00')),
#  (50.513397216796875, Timestamp('2019-11-10 09:48:00')),
#  (46.53252029418945, Timestamp('2019-11-10 10:22:00')),
#  (46.6761589050293, Timestamp('2019-11-10 10:55:00')),
#  (47.21651840209961, Timestamp('2019-11-10 11:26:00')),
#  (47.32596206665039, Timestamp('2019-11-10 11:58:00')),
#  (47.722679138183594, Timestamp('2019-11-10 12:29:00')),
#  (49.022281646728516, Timestamp('2019-11-10 13:02:00')),
#  (50.47920227050781, Timestamp('2019-11-10 18:17:00')),
#  (53.96760177612305, Timestamp('2019-11-10 18:37:00')),
#  (50.7801628112793, Timestamp('2019-11-10 18:59:00')),
#  (51.245277404785156, Timestamp('2019-11-10 19:20:00')),
#  (51.08796310424805, Timestamp('2019-11-10 19:41:00')),
#  (49.993560791015625, Timestamp('2019-11-10 20:03:00')),
#  (49.35744094848633, Timestamp('2019-11-10 20:26:00')),
#  (49.23432159423828, Timestamp('2019-11-10 20:49:00')),
#  (48.78972244262695, Timestamp('2019-11-10 21:14:00')),
#  (48.776039123535156, Timestamp('2019-11-10 21:37:00')),
#  (48.68027877807617, Timestamp('2019-11-10 22:02:00')),
#  (49.364280700683594, Timestamp('2019-11-10 22:26:00')),
#  (48.81708526611328, Timestamp('2019-11-10 22:52:00')),
#  (51.655677795410156, Timestamp('2019-11-10 23:18:00')),
#  (48.263038635253906, Timestamp('2019-11-10 23:47:00')),
#  (48.42720031738281, Timestamp('2019-11-11 00:10:00')),
#  (48.53664016723633, Timestamp('2019-11-11 00:36:00')),
#  (47.85264205932617, Timestamp('2019-11-11 01:03:00')),
#  (48.194637298583984, Timestamp('2019-11-11 01:30:00')),
#  (48.38615798950195, Timestamp('2019-11-11 03:27:00')),
#  (49.1317253112793, Timestamp('2019-11-11 03:52:00')),
#  (48.194637298583984, Timestamp('2019-11-11 04:19:00')),
#  (48.0783576965332, Timestamp('2019-11-11 04:46:00')),
#  (48.3177604675293, Timestamp('2019-11-11 05:11:00')),
#  (48.345123291015625, Timestamp('2019-11-11 05:38:00')),
#  (48.393001556396484, Timestamp('2019-11-11 06:04:00')),
#  (50.82120132446289, Timestamp('2019-11-11 06:31:00')),
#  (47.674800872802734, Timestamp('2019-11-11 07:00:00')),
#  (47.54484558105469, Timestamp('2019-11-11 07:26:00')),
#  (48.3177604675293, Timestamp('2019-11-11 07:52:00')),
#  (47.40119934082031, Timestamp('2019-11-11 08:21:00')),
#  (49.637882232666016, Timestamp('2019-11-11 08:46:00')),
#  (50.69123840332031, Timestamp('2019-11-11 09:12:00')),
#  (48.092041015625, Timestamp('2019-11-11 09:40:00')),
#  (47.319122314453125, Timestamp('2019-11-11 10:07:00')),
#  (48.605037689208984, Timestamp('2019-11-11 11:15:00')),
#  (47.2507209777832, Timestamp('2019-11-11 11:42:00')),
#  (47.18915939331055, Timestamp('2019-11-11 12:08:00')),
#  (48.16728210449219, Timestamp('2019-11-11 12:36:00')),
#  (47.681640625, Timestamp('2019-11-11 13:01:00')),
#  (47.667964935302734, Timestamp('2019-11-11 13:26:00')),
#  (47.264400482177734, Timestamp('2019-11-11 13:53:00')),
#  (49.04279708862305, Timestamp('2019-11-11 15:10:00')),
#  (51.20424270629883, Timestamp('2019-11-11 15:35:00')),
#  (48.61872100830078, Timestamp('2019-11-11 16:01:00')),
#  (47.7021598815918, Timestamp('2019-11-11 16:27:00')),
#  (49.20012283325195, Timestamp('2019-11-11 16:53:00')),
#  (48.611881256103516, Timestamp('2019-11-11 17:44:00')),
#  (48.94020462036133, Timestamp('2019-11-11 18:09:00')),
#  (48.64608383178711, Timestamp('2019-11-11 18:34:00')),
#  (47.8731575012207, Timestamp('2019-11-11 18:59:00')),
#  (48.263038635253906, Timestamp('2019-11-11 19:24:00')),
#  (47.17548370361328, Timestamp('2019-11-11 19:51:00')),
#  (47.278079986572266, Timestamp('2019-11-11 20:16:00')),
#  (49.35060119628906, Timestamp('2019-11-11 21:02:00')),
#  (48.78972244262695, Timestamp('2019-11-11 21:27:00')),
#  (48.52980041503906, Timestamp('2019-11-11 21:51:00')),
#  (47.729522705078125, Timestamp('2019-11-11 22:17:00')),
#  (48.304080963134766, Timestamp('2019-11-11 22:42:00')),
#  (47.60639953613281, Timestamp('2019-11-11 23:08:00')),
#  (48.97439956665039, Timestamp('2019-11-12 00:19:00')),
#  (52.03187942504883, Timestamp('2019-11-12 00:45:00')),
#  (48.776039123535156, Timestamp('2019-11-12 01:12:00')),
#  (48.17412185668945, Timestamp('2019-11-12 01:38:00')),
#  (48.249359130859375, Timestamp('2019-11-12 02:04:00')),
#  (48.906002044677734, Timestamp('2019-11-12 02:30:00')),
#  (48.03048324584961, Timestamp('2019-11-12 02:56:00')),
#  (51.66936111450195, Timestamp('2019-11-12 04:06:00')),
#  (48.81708526611328, Timestamp('2019-11-12 04:32:00')),
#  (47.76372146606445, Timestamp('2019-11-12 04:58:00')),
#  (47.75688171386719, Timestamp('2019-11-12 05:24:00')),
#  (48.14676284790039, Timestamp('2019-11-12 05:49:00')),
#  (48.52980041503906, Timestamp('2019-11-12 07:15:00')),
#  (53.04420471191406, Timestamp('2019-11-12 07:40:00')),
#  (48.714481353759766, Timestamp('2019-11-12 08:07:00')),
#  (47.613243103027344, Timestamp('2019-11-12 08:35:00')),
#  (47.54484558105469, Timestamp('2019-11-12 09:01:00')),
#  (48.659759521484375, Timestamp('2019-11-12 09:27:00')),
#  (49.09067916870117, Timestamp('2019-11-12 09:52:00')),
#  (48.393001556396484, Timestamp('2019-11-12 10:17:00')),
#  (48.00996017456055, Timestamp('2019-11-12 10:44:00')),
#  (47.750038146972656, Timestamp('2019-11-12 11:09:00')),
#  (47.80475997924805, Timestamp('2019-11-12 11:33:00')),
#  (48.50244140625, Timestamp('2019-11-12 12:00:00')),
#  (48.290401458740234, Timestamp('2019-11-12 12:26:00')),
#  (49.1043586730957, Timestamp('2019-11-12 13:15:00')),
#  (48.64608383178711, Timestamp('2019-11-12 13:40:00')),
#  (48.46824264526367, Timestamp('2019-11-12 14:03:00')),
#  (49.1043586730957, Timestamp('2019-11-12 14:28:00')),
#  (48.52980041503906, Timestamp('2019-11-12 14:53:00')),
#  (49.02912139892578, Timestamp('2019-11-12 15:17:00')),
#  (48.14676284790039, Timestamp('2019-11-12 15:43:00')),
#  (48.53664016723633, Timestamp('2019-11-12 16:08:00')),
#  (48.2835578918457, Timestamp('2019-11-12 16:33:00')),
#  (49.23432159423828, Timestamp('2019-11-12 16:59:00')),
#  (47.579036712646484, Timestamp('2019-11-12 17:26:00')),
#  (48.35879898071289, Timestamp('2019-11-12 17:52:00')),
#  (49.43952178955078, Timestamp('2019-11-12 18:19:00')),
#  (51.901920318603516, Timestamp('2019-11-12 19:11:00')),
#  (47.8936767578125, Timestamp('2019-11-12 19:38:00')),
#  (48.044158935546875, Timestamp('2019-11-12 20:03:00')),
#  (47.524322509765625, Timestamp('2019-11-12 20:30:00')),
#  (47.271240234375, Timestamp('2019-11-12 20:57:00')),
#  (46.94292068481445, Timestamp('2019-11-12 21:23:00')),
#  (47.32596206665039, Timestamp('2019-11-12 21:52:00')),
#  (47.989444732666016, Timestamp('2019-11-12 22:18:00')),
#  (48.11940002441406, Timestamp('2019-11-12 22:45:00')),
#  (48.2835578918457, Timestamp('2019-11-12 23:11:00')),
#  (47.284915924072266, Timestamp('2019-11-12 23:41:00')),
#  (46.2315559387207, Timestamp('2019-11-13 00:10:00')),
#  (49.24115753173828, Timestamp('2019-11-13 00:44:00')),
#  (47.8868408203125, Timestamp('2019-11-13 01:10:00')),
#  (50.82803726196289, Timestamp('2019-11-13 01:36:00')),
#  (47.79108428955078, Timestamp('2019-11-13 02:03:00')),
#  (47.23704147338867, Timestamp('2019-11-13 02:36:00')),
#  (47.65428161621094, Timestamp('2019-11-13 03:00:00')),
#  (47.60639953613281, Timestamp('2019-11-13 03:27:00')),
#  (47.55852127075195, Timestamp('2019-11-13 03:54:00')),
#  (47.743202209472656, Timestamp('2019-11-13 04:20:00')),
#  (47.0865592956543, Timestamp('2019-11-13 04:48:00')),
#  (46.53936004638672, Timestamp('2019-11-13 05:16:00')),
#  (47.8663215637207, Timestamp('2019-11-13 06:11:00')),
#  (47.85264205932617, Timestamp('2019-11-13 06:39:00')),
#  (47.531158447265625, Timestamp('2019-11-13 07:05:00')),
#  (47.76372146606445, Timestamp('2019-11-13 07:31:00')),
#  (46.53252029418945, Timestamp('2019-11-13 07:59:00')),
#  (48.5161247253418, Timestamp('2019-11-13 08:26:00')),
#  (48.22200012207031, Timestamp('2019-11-13 08:55:00')),
#  (48.098880767822266, Timestamp('2019-11-13 09:21:00')),
#  (47.989444732666016, Timestamp('2019-11-13 09:48:00')),
#  (48.365638732910156, Timestamp('2019-11-13 10:14:00')),
#  (48.67344284057617, Timestamp('2019-11-13 10:39:00')),
#  (48.59136199951172, Timestamp('2019-11-13 11:05:00')),
#  (49.890960693359375, Timestamp('2019-11-13 11:30:00')),
#  (49.44636154174805, Timestamp('2019-11-13 11:55:00')),
#  (48.776039123535156, Timestamp('2019-11-13 12:21:00')),
#  (48.50244140625, Timestamp('2019-11-13 12:47:00')),
#  (50.862239837646484, Timestamp('2019-11-13 13:11:00')),
#  (49.09067916870117, Timestamp('2019-11-13 13:37:00')),
#  (47.50379943847656, Timestamp('2019-11-13 14:03:00')),
#  (47.941558837890625, Timestamp('2019-11-13 14:29:00')),
#  (47.32596206665039, Timestamp('2019-11-13 14:57:00')),
#  (49.48055648803711, Timestamp('2019-11-13 15:47:00')),
#  (48.454559326171875, Timestamp('2019-11-13 16:14:00')),
#  (48.87864303588867, Timestamp('2019-11-13 17:08:00')),
#  (50.02775955200195, Timestamp('2019-11-13 17:33:00')),
#  (48.94020462036133, Timestamp('2019-11-13 17:59:00')),
#  (48.851280212402344, Timestamp('2019-11-13 18:26:00')),
#  (48.605037689208984, Timestamp('2019-11-13 18:50:00')),
#  (50.191917419433594, Timestamp('2019-11-13 19:16:00')),
#  (48.776039123535156, Timestamp('2019-11-13 19:43:00')),
#  (48.42720031738281, Timestamp('2019-11-13 20:09:00')),
#  (48.331443786621094, Timestamp('2019-11-13 20:36:00')),
#  (48.1125602722168, Timestamp('2019-11-13 21:02:00')),
#  (48.03048324584961, Timestamp('2019-11-13 21:30:00')),
#  (48.700801849365234, Timestamp('2019-11-13 21:57:00')),
#  (47.8663215637207, Timestamp('2019-11-13 22:23:00')),
#  (51.245277404785156, Timestamp('2019-11-13 22:50:00')),
#  (50.15087890625, Timestamp('2019-11-13 23:16:00')),
#  (50.978519439697266, Timestamp('2019-11-13 23:43:00')),
#  (48.051002502441406, Timestamp('2019-11-14 00:11:00')),
#  (47.784244537353516, Timestamp('2019-11-14 00:37:00')),
#  (48.43403625488281, Timestamp('2019-11-14 01:04:00')),
#  (47.40803527832031, Timestamp('2019-11-14 01:30:00')),
#  (47.24388122558594, Timestamp('2019-11-14 01:57:00')),
#  (46.854000091552734, Timestamp('2019-11-14 02:25:00')),
#  (48.851280212402344, Timestamp('2019-11-14 07:14:00')),
#  (53.481964111328125, Timestamp('2019-11-14 07:37:00')),
#  (48.57084655761719, Timestamp('2019-11-14 08:02:00')),
#  (47.613243103027344, Timestamp('2019-11-14 08:27:00')),
#  (47.29176330566406, Timestamp('2019-11-14 08:54:00')),
#  (47.10023880004883, Timestamp('2019-11-14 09:22:00')),
#  (50.185081481933594, Timestamp('2019-11-14 09:46:00')),
#  (47.70899963378906, Timestamp('2019-11-14 10:12:00')),
#  (48.20832443237305, Timestamp('2019-11-14 10:37:00')),
#  (47.784244537353516, Timestamp('2019-11-14 11:01:00')),
#  (47.35332489013672, Timestamp('2019-11-14 11:29:00')),
#  (47.982601165771484, Timestamp('2019-11-14 11:53:00')),
#  (47.49696350097656, Timestamp('2019-11-14 12:21:00')),
#  (50.547603607177734, Timestamp('2019-11-14 14:12:00')),
#  (53.56403732299805, Timestamp('2019-11-14 14:37:00')),
#  (49.23432159423828, Timestamp('2019-11-14 15:04:00')),
#  (49.330081939697266, Timestamp('2019-11-14 15:27:00')),
#  (48.693965911865234, Timestamp('2019-11-14 15:53:00')),
#  (48.8923225402832, Timestamp('2019-11-14 16:19:00')),
#  (48.1057243347168, Timestamp('2019-11-14 16:45:00')),
#  (47.072879791259766, Timestamp('2019-11-14 17:15:00')),
#  (53.6598014831543, Timestamp('2019-11-14 18:08:00')),
#  (48.967559814453125, Timestamp('2019-11-14 18:33:00')),
#  (49.45320129394531, Timestamp('2019-11-14 18:57:00')),
#  (48.50244140625, Timestamp('2019-11-14 19:23:00')),
#  (48.044158935546875, Timestamp('2019-11-14 19:49:00')),
#  (48.81708526611328, Timestamp('2019-11-14 20:28:00')),
#  (50.212440490722656, Timestamp('2019-11-14 20:52:00')),
#  (49.692604064941406, Timestamp('2019-11-14 21:16:00')),
#  (48.550323486328125, Timestamp('2019-11-14 21:41:00')),
#  (48.42720031738281, Timestamp('2019-11-14 22:05:00')),
#  (49.993560791015625, Timestamp('2019-11-14 22:56:00')),
#  (50.15087890625, Timestamp('2019-11-14 23:19:00')),
#  (49.063323974609375, Timestamp('2019-11-14 23:43:00')),
#  (49.008602142333984, Timestamp('2019-11-15 00:08:00')),
#  (49.542118072509766, Timestamp('2019-11-15 00:31:00')),
#  (48.80339813232422, Timestamp('2019-11-15 00:55:00')),
#  (48.461402893066406, Timestamp('2019-11-15 01:20:00')),
#  (47.750038146972656, Timestamp('2019-11-15 01:46:00')),
#  (48.919677734375, Timestamp('2019-11-15 02:11:00')),
#  (49.172760009765625, Timestamp('2019-11-15 02:36:00')),
#  (48.20832443237305, Timestamp('2019-11-15 03:01:00')),
#  (47.96892166137695, Timestamp('2019-11-15 03:26:00')),
#  (48.611881256103516, Timestamp('2019-11-15 09:18:00')),
#  (49.432682037353516, Timestamp('2019-11-15 09:46:00')),
#  (47.6953239440918, Timestamp('2019-11-15 10:15:00')),
#  (47.00448226928711, Timestamp('2019-11-15 10:43:00')),
#  (47.13444519042969, Timestamp('2019-11-15 11:10:00')),
#  (48.666603088378906, Timestamp('2019-11-15 11:38:00')),
#  (48.74184036254883, Timestamp('2019-11-15 12:48:00')),
#  (48.085205078125, Timestamp('2019-11-15 13:14:00')),
#  (48.365638732910156, Timestamp('2019-11-15 13:38:00')),
#  (47.4696044921875, Timestamp('2019-11-15 14:06:00')),
#  (47.03867721557617, Timestamp('2019-11-15 14:30:00')),
#  (48.8991584777832, Timestamp('2019-11-15 15:51:00')),
#  (48.46824264526367, Timestamp('2019-11-15 16:16:00')),
#  (50.191917419433594, Timestamp('2019-11-15 16:41:00')),
#  (46.970279693603516, Timestamp('2019-11-15 17:07:00')),
#  (47.9005241394043, Timestamp('2019-11-15 17:33:00')),
#  (47.23020553588867, Timestamp('2019-11-15 17:59:00')),
#  (47.81159973144531, Timestamp('2019-11-15 18:24:00')),
#  (47.79108428955078, Timestamp('2019-11-15 18:49:00')),
#  (48.67344284057617, Timestamp('2019-11-15 19:13:00')),
#  (49.37796401977539, Timestamp('2019-11-15 19:36:00')),
#  (48.1125602722168, Timestamp('2019-11-15 20:02:00')),
#  (48.59136199951172, Timestamp('2019-11-15 20:27:00')),
#  (47.223358154296875, Timestamp('2019-11-15 20:52:00')),
#  (48.16728210449219, Timestamp('2019-11-15 21:17:00')),
#  (49.49424362182617, Timestamp('2019-11-15 21:43:00')),
#  (47.7021598815918, Timestamp('2019-11-15 22:08:00')),
#  (48.73500061035156, Timestamp('2019-11-15 22:34:00')),
#  (49.077003479003906, Timestamp('2019-11-15 23:00:00')),
#  (48.851280212402344, Timestamp('2019-11-15 23:25:00')),
#  (48.447723388671875, Timestamp('2019-11-15 23:51:00')),
#  (47.55852127075195, Timestamp('2019-11-16 00:18:00')),
#  (48.18096160888672, Timestamp('2019-11-16 01:09:00')),
#  (48.851280212402344, Timestamp('2019-11-16 01:35:00')),
#  (47.6953239440918, Timestamp('2019-11-16 02:00:00')),
#  (47.052364349365234, Timestamp('2019-11-16 02:26:00')),
#  (46.47096252441406, Timestamp('2019-11-16 02:52:00')),
#  (47.934722900390625, Timestamp('2019-11-16 03:28:00')),
#  (49.67892074584961, Timestamp('2019-11-16 03:51:00')),
#  (48.044158935546875, Timestamp('2019-11-16 04:16:00')),
#  (48.61872100830078, Timestamp('2019-11-16 04:41:00')),
#  (47.56536102294922, Timestamp('2019-11-16 05:06:00')),
#  (47.0797233581543, Timestamp('2019-11-16 05:32:00')),
#  (47.168643951416016, Timestamp('2019-11-16 06:01:00')),
#  (47.39435958862305, Timestamp('2019-11-16 06:25:00')),
#  (50.513397216796875, Timestamp('2019-11-16 06:48:00')),
#  (48.00996017456055, Timestamp('2019-11-16 07:13:00')),
#  (47.91420364379883, Timestamp('2019-11-16 07:37:00')),
#  (46.6761589050293, Timestamp('2019-11-16 08:03:00')),
#  (49.849918365478516, Timestamp('2019-11-16 11:28:00')),
#  (49.38479995727539, Timestamp('2019-11-16 11:52:00')),
#  (49.40532302856445, Timestamp('2019-11-16 12:17:00')),
#  (51.10163879394531, Timestamp('2019-11-16 12:39:00')),
#  (48.981239318847656, Timestamp('2019-11-16 13:02:00')),
#  (49.24800109863281, Timestamp('2019-11-16 13:26:00')),
#  (49.14540100097656, Timestamp('2019-11-16 13:50:00')),
#  (50.814361572265625, Timestamp('2019-11-16 14:13:00')),
#  (50.84172439575195, Timestamp('2019-11-16 14:36:00')),
#  (51.10163879394531, Timestamp('2019-11-16 15:00:00')),
#  (48.50244140625, Timestamp('2019-11-16 15:25:00')),
#  (50.253482818603516, Timestamp('2019-11-16 15:49:00')),
#  (48.83760070800781, Timestamp('2019-11-16 16:13:00')),
#  (49.59000015258789, Timestamp('2019-11-16 16:38:00')),
#  (48.85811996459961, Timestamp('2019-11-16 17:04:00')),
#  (48.926517486572266, Timestamp('2019-11-16 17:29:00')),
#  (49.35744094848633, Timestamp('2019-11-16 17:52:00')),
#  (48.88548278808594, Timestamp('2019-11-16 18:17:00')),
#  (49.282203674316406, Timestamp('2019-11-16 18:41:00')),
#  (50.7527961730957, Timestamp('2019-11-16 19:04:00')),
#  (49.26852035522461, Timestamp('2019-11-16 19:28:00')),
#  (48.9333610534668, Timestamp('2019-11-16 19:53:00')),
#  (48.639244079589844, Timestamp('2019-11-16 20:17:00')),
#  (48.56399917602539, Timestamp('2019-11-16 20:41:00')),
#  (48.509281158447266, Timestamp('2019-11-16 21:06:00')),
#  (48.65291976928711, Timestamp('2019-11-16 21:31:00')),
#  (48.59136199951172, Timestamp('2019-11-16 21:55:00')),
#  (51.75828170776367, Timestamp('2019-11-16 22:19:00')),
#  (49.37796401977539, Timestamp('2019-11-16 22:44:00')),
#  (49.20696258544922, Timestamp('2019-11-16 23:08:00')),
#  (48.57084655761719, Timestamp('2019-11-16 23:33:00')),
#  (48.2835578918457, Timestamp('2019-11-16 23:58:00')),
#  (49.44636154174805, Timestamp('2019-11-17 00:23:00')),
#  (47.96892166137695, Timestamp('2019-11-17 00:48:00')),
#  (48.1057243347168, Timestamp('2019-11-17 01:13:00')),
#  (47.517478942871094, Timestamp('2019-11-17 01:39:00')),
#  (47.278079986572266, Timestamp('2019-11-17 02:04:00')),
#  (47.517478942871094, Timestamp('2019-11-17 02:29:00')),
#  (37.031761169433594, Timestamp('2019-11-17 04:15:00')),
#  (51.128997802734375, Timestamp('2019-11-17 04:43:00')),
#  (48.776039123535156, Timestamp('2019-11-17 05:08:00')),
#  (48.714481353759766, Timestamp('2019-11-17 05:32:00')),
#  (47.9005241394043, Timestamp('2019-11-17 05:58:00')),
#  (47.75688171386719, Timestamp('2019-11-17 06:25:00')),
#  (50.38344192504883, Timestamp('2019-11-17 06:49:00')),
#  (51.32052230834961, Timestamp('2019-11-17 07:14:00')),
#  (47.4696044921875, Timestamp('2019-11-17 07:41:00')),
#  (47.54484558105469, Timestamp('2019-11-17 08:05:00')),
#  (47.585880279541016, Timestamp('2019-11-17 08:31:00')),
#  (47.613243103027344, Timestamp('2019-11-17 08:58:00')),
#  (48.22200012207031, Timestamp('2019-11-17 10:30:00')),
#  (48.00312042236328, Timestamp('2019-11-17 10:57:00')),
#  (47.8868408203125, Timestamp('2019-11-17 11:20:00')),
#  (48.051002502441406, Timestamp('2019-11-17 11:45:00')),
#  (47.39435958862305, Timestamp('2019-11-17 12:10:00')),
#  (47.880001068115234, Timestamp('2019-11-17 12:36:00')),
#  (48.68027877807617, Timestamp('2019-11-17 14:12:00')),
#  (50.73228073120117, Timestamp('2019-11-17 14:37:00')),
#  (47.715843200683594, Timestamp('2019-11-17 15:02:00')),
#  (48.98808288574219, Timestamp('2019-11-17 15:47:00')),
#  (47.97576141357422, Timestamp('2019-11-17 16:12:00')),
#  (49.35744094848633, Timestamp('2019-11-17 16:35:00')),
#  (49.569480895996094, Timestamp('2019-11-17 17:01:00')),
#  (47.62008285522461, Timestamp('2019-11-17 18:13:00')),
#  (47.80475997924805, Timestamp('2019-11-17 18:39:00')),
#  (49.19328308105469, Timestamp('2019-11-17 19:03:00')),
#  (47.996280670166016, Timestamp('2019-11-17 19:27:00')),
#  (48.06467819213867, Timestamp('2019-11-17 19:52:00')),
#  (47.65428161621094, Timestamp('2019-11-17 20:19:00')),
#  (48.310916900634766, Timestamp('2019-11-17 20:41:00')),
#  (47.264400482177734, Timestamp('2019-11-17 21:07:00')),
#  (48.57768249511719, Timestamp('2019-11-17 23:36:00')),
#  (48.201480865478516, Timestamp('2019-11-18 00:02:00')),
#  (47.941558837890625, Timestamp('2019-11-18 00:26:00')),
#  (47.55852127075195, Timestamp('2019-11-18 00:51:00')),
#  (48.023643493652344, Timestamp('2019-11-18 01:17:00')),
#  (46.8745231628418, Timestamp('2019-11-18 01:45:00')),
#  (47.127601623535156, Timestamp('2019-11-18 02:10:00')),
#  (48.05784225463867, Timestamp('2019-11-18 03:09:00')),
#  (47.83211898803711, Timestamp('2019-11-18 03:34:00')),
#  (47.50379943847656, Timestamp('2019-11-18 03:59:00')),
#  (47.9005241394043, Timestamp('2019-11-18 04:25:00')),
#  (49.733642578125, Timestamp('2019-11-18 05:09:00')),
#  (48.598201751708984, Timestamp('2019-11-18 05:34:00')),
#  (47.579036712646484, Timestamp('2019-11-18 06:00:00')),
#  (48.7281608581543, Timestamp('2019-11-18 07:25:00')),
#  (48.73500061035156, Timestamp('2019-11-18 07:50:00')),
#  (47.80475997924805, Timestamp('2019-11-18 08:16:00')),
#  (50.492881774902344, Timestamp('2019-11-18 18:50:00')),
#  (49.870445251464844, Timestamp('2019-11-18 19:13:00')),
#  (49.08384323120117, Timestamp('2019-11-18 19:36:00')),
#  (48.967559814453125, Timestamp('2019-11-18 19:59:00')),
#  (50.759639739990234, Timestamp('2019-11-18 20:22:00')),
#  (49.3232421875, Timestamp('2019-11-18 20:45:00')),
#  (49.48055648803711, Timestamp('2019-11-18 21:10:00')),
#  (48.24251937866211, Timestamp('2019-11-18 21:36:00')),
#  (48.864959716796875, Timestamp('2019-11-18 22:00:00')),
#  (49.65155792236328, Timestamp('2019-11-18 22:24:00')),
#  (48.550323486328125, Timestamp('2019-11-18 22:49:00')),
#  (48.8991584777832, Timestamp('2019-11-18 23:13:00')),
#  (49.69944381713867, Timestamp('2019-11-18 23:36:00')),
#  (50.287681579589844, Timestamp('2019-11-19 00:00:00')),
#  (49.870445251464844, Timestamp('2019-11-19 00:25:00')),
#  (50.15087890625, Timestamp('2019-11-19 00:50:00')),
#  (51.91559982299805, Timestamp('2019-11-19 01:15:00')),
#  (48.41352081298828, Timestamp('2019-11-19 01:41:00')),
#  (48.12623977661133, Timestamp('2019-11-19 02:06:00')),
#  (48.810237884521484, Timestamp('2019-11-19 02:30:00')),
#  (47.319122314453125, Timestamp('2019-11-19 03:00:00')),
#  (47.880001068115234, Timestamp('2019-11-19 03:21:00')),
#  (47.674800872802734, Timestamp('2019-11-19 03:45:00')),
#  (47.729522705078125, Timestamp('2019-11-19 04:10:00')),
#  (48.74184036254883, Timestamp('2019-11-19 04:34:00')),
#  (47.613243103027344, Timestamp('2019-11-19 04:58:00')),
#  (48.2835578918457, Timestamp('2019-11-19 06:37:00')),
#  (48.5161247253418, Timestamp('2019-11-19 07:00:00')),
#  (49.20012283325195, Timestamp('2019-11-19 07:24:00')),
#  (50.082481384277344, Timestamp('2019-11-19 07:48:00')),
#  (46.83348083496094, Timestamp('2019-11-19 08:14:00')),
#  (47.223358154296875, Timestamp('2019-11-19 08:50:00')),
#  (47.34648132324219, Timestamp('2019-11-19 09:15:00')),
#  (47.476444244384766, Timestamp('2019-11-19 09:39:00')),
#  (46.867679595947266, Timestamp('2019-11-19 10:06:00')),
#  (46.662479400634766, Timestamp('2019-11-19 10:28:00')),
#  (36.491397857666016, Timestamp('2019-11-19 11:00:00')),
#  (46.402557373046875, Timestamp('2019-11-19 11:18:00')),
#  (50.3697624206543, Timestamp('2019-11-19 11:43:00')),
#  (48.46824264526367, Timestamp('2019-11-19 12:08:00')),
#  (48.509281158447266, Timestamp('2019-11-19 12:32:00')),
#  (50.458675384521484, Timestamp('2019-11-19 12:55:00')),
#  (46.77875900268555, Timestamp('2019-11-19 13:20:00')),
#  (46.10844421386719, Timestamp('2019-11-19 13:47:00')),
#  (46.0400390625, Timestamp('2019-11-19 14:09:00')),
#  (44.706241607666016, Timestamp('2019-11-19 14:41:00')),
#  (46.53936004638672, Timestamp('2019-11-19 15:14:00')),
#  (46.717201232910156, Timestamp('2019-11-19 15:36:00')),
#  (47.435401916503906, Timestamp('2019-11-19 15:59:00')),
#  (46.59408187866211, Timestamp('2019-11-19 16:23:00')),
#  (46.956600189208984, Timestamp('2019-11-19 16:47:00')),
#  (46.546199798583984, Timestamp('2019-11-19 17:13:00')),
#  (46.997642517089844, Timestamp('2019-11-19 18:38:00')),
#  (48.11940002441406, Timestamp('2019-11-19 19:02:00')),
#  (46.99079895019531, Timestamp('2019-11-19 19:27:00')),
#  (46.71036148071289, Timestamp('2019-11-19 19:52:00')),
#  (46.06740188598633, Timestamp('2019-11-19 20:16:00')),
#  (46.51884460449219, Timestamp('2019-11-19 20:41:00')),
#  (46.081085205078125, Timestamp('2019-11-19 21:07:00')),
#  (46.55988311767578, Timestamp('2019-11-19 21:31:00')),
#  (46.792442321777344, Timestamp('2019-11-19 21:56:00')),
#  (49.063323974609375, Timestamp('2019-11-19 22:20:00')),
#  (47.39435958862305, Timestamp('2019-11-19 22:43:00')),
#  (46.82664108276367, Timestamp('2019-11-19 23:08:00')),
#  (46.77191925048828, Timestamp('2019-11-19 23:32:00')),
#  (47.8663215637207, Timestamp('2019-11-19 23:57:00')),
#  (48.14676284790039, Timestamp('2019-11-20 01:04:00')),
#  (47.0660400390625, Timestamp('2019-11-20 01:29:00')),
#  (46.59408187866211, Timestamp('2019-11-20 01:53:00')),
#  (46.49832534790039, Timestamp('2019-11-20 02:19:00')),
#  (47.127601623535156, Timestamp('2019-11-20 02:45:00')),
#  (47.524322509765625, Timestamp('2019-11-20 03:09:00')),
#  (49.55580139160156, Timestamp('2019-11-20 03:33:00')),
#  (47.40119934082031, Timestamp('2019-11-20 03:58:00')),
#  (46.76508331298828, Timestamp('2019-11-20 04:23:00')),
#  (47.380680084228516, Timestamp('2019-11-20 04:47:00')),
#  (48.47508239746094, Timestamp('2019-11-20 05:51:00')),
#  (47.750038146972656, Timestamp('2019-11-20 06:14:00')),
#  (47.32596206665039, Timestamp('2019-11-20 06:37:00')),
#  (46.99079895019531, Timestamp('2019-11-20 07:02:00')),
#  (47.271240234375, Timestamp('2019-11-20 07:27:00')),
#  (47.0865592956543, Timestamp('2019-11-20 07:50:00')),
#  (49.220638275146484, Timestamp('2019-11-20 08:14:00')),
#  (48.051002502441406, Timestamp('2019-11-20 08:55:00')),
#  (48.01679611206055, Timestamp('2019-11-20 09:20:00')),
#  (51.382083892822266, Timestamp('2019-11-20 09:43:00')),
#  (47.44224166870117, Timestamp('2019-11-20 10:08:00')),
#  (48.639244079589844, Timestamp('2019-11-20 10:31:00')),
#  (48.7076416015625, Timestamp('2019-11-20 10:55:00')),
#  (48.58452224731445, Timestamp('2019-11-20 11:19:00')),
#  (47.79108428955078, Timestamp('2019-11-20 11:44:00')),
#  (47.524322509765625, Timestamp('2019-11-20 12:09:00')),
#  (47.4627571105957, Timestamp('2019-11-20 12:33:00')),
#  (47.223358154296875, Timestamp('2019-11-20 12:58:00')),
#  (47.0455207824707, Timestamp('2019-11-20 13:23:00')),
#  (48.46824264526367, Timestamp('2019-11-20 14:17:00')),
#  (49.843082427978516, Timestamp('2019-11-20 15:32:00')),
#  (49.542118072509766, Timestamp('2019-11-20 15:53:00')),
#  (52.61328125, Timestamp('2019-11-20 16:16:00')),
#  (49.20696258544922, Timestamp('2019-11-20 16:41:00')),
#  (48.776039123535156, Timestamp('2019-11-20 17:05:00')),
#  (49.18644714355469, Timestamp('2019-11-20 17:28:00')),
#  (49.391639709472656, Timestamp('2019-11-20 17:52:00')),
#  (53.97444152832031, Timestamp('2019-11-20 18:15:00')),
#  (49.04279708862305, Timestamp('2019-11-20 18:39:00')),
#  (49.070159912109375, Timestamp('2019-11-20 19:03:00')),
#  (48.461402893066406, Timestamp('2019-11-20 19:28:00')),
#  (49.063323974609375, Timestamp('2019-11-20 20:16:00')),
#  (49.1385612487793, Timestamp('2019-11-20 20:41:00')),
#  (50.17140197753906, Timestamp('2019-11-20 21:04:00')),
#  (49.487403869628906, Timestamp('2019-11-20 21:29:00')),
#  (48.73500061035156, Timestamp('2019-11-20 21:54:00')),
#  (49.69944381713867, Timestamp('2019-11-20 22:19:00')),
#  (48.447723388671875, Timestamp('2019-11-20 22:45:00')),
#  (50.23979949951172, Timestamp('2019-11-20 23:08:00')),
#  (49.14540100097656, Timestamp('2019-11-20 23:33:00')),
#  (49.77467727661133, Timestamp('2019-11-20 23:57:00')),
#  (48.12623977661133, Timestamp('2019-11-21 00:22:00')),
#  (49.521602630615234, Timestamp('2019-11-21 00:48:00')),
#  (49.43952178955078, Timestamp('2019-11-21 01:41:00')),
#  (49.576324462890625, Timestamp('2019-11-21 02:24:00')),
#  (49.7267951965332, Timestamp('2019-11-21 02:49:00')),
#  (49.20012283325195, Timestamp('2019-11-21 03:13:00')),
#  (49.124881744384766, Timestamp('2019-11-21 03:37:00')),
#  (49.220638275146484, Timestamp('2019-11-21 04:01:00')),
#  (49.15224075317383, Timestamp('2019-11-21 04:26:00')),
#  (48.912841796875, Timestamp('2019-11-21 04:50:00')),
#  (50.50655746459961, Timestamp('2019-11-21 05:11:00')),
#  (49.425846099853516, Timestamp('2019-11-21 05:35:00')),
#  (49.71311950683594, Timestamp('2019-11-21 05:58:00')),
#  (53.30412292480469, Timestamp('2019-11-21 06:21:00')),
#  (50.63652038574219, Timestamp('2019-11-21 06:44:00')),
#  (49.24115753173828, Timestamp('2019-11-21 07:09:00')),
#  (50.49972152709961, Timestamp('2019-11-21 07:33:00')),
#  (48.24251937866211, Timestamp('2019-11-21 07:58:00')),
#  (47.65428161621094, Timestamp('2019-11-21 08:22:00')),
#  (48.73500061035156, Timestamp('2019-11-21 08:46:00')),
#  (67.71600341796875, Timestamp('2019-11-21 09:25:00')),
#  (48.67344284057617, Timestamp('2019-11-21 09:47:00')),
#  (48.52980041503906, Timestamp('2019-11-21 10:12:00')),
#  (48.38615798950195, Timestamp('2019-11-21 10:34:00')),
#  (49.952518463134766, Timestamp('2019-11-21 10:57:00')),
#  (47.94839859008789, Timestamp('2019-11-21 11:22:00')),
#  (47.517478942871094, Timestamp('2019-11-21 11:46:00')),
#  (47.0455207824707, Timestamp('2019-11-21 12:11:00')),
#  (52.05240249633789, Timestamp('2019-11-21 12:58:00')),
#  (47.94839859008789, Timestamp('2019-11-21 13:22:00')),
#  (50.32872009277344, Timestamp('2019-11-21 13:47:00')),
#  (47.989444732666016, Timestamp('2019-11-21 14:12:00')),
#  (49.425846099853516, Timestamp('2019-11-21 15:22:00')),
#  (48.256202697753906, Timestamp('2019-11-21 15:49:00')),
#  (48.085205078125, Timestamp('2019-11-21 16:12:00')),
#  (47.91420364379883, Timestamp('2019-11-21 16:35:00')),
#  (47.50379943847656, Timestamp('2019-11-21 17:00:00')),
#  (46.997642517089844, Timestamp('2019-11-21 17:27:00')),
#  (50.513397216796875, Timestamp('2019-11-21 18:15:00')),
#  (48.639244079589844, Timestamp('2019-11-21 18:40:00')),
#  (47.941558837890625, Timestamp('2019-11-21 19:04:00')),
#  (47.715843200683594, Timestamp('2019-11-21 19:27:00')),
#  (47.367000579833984, Timestamp('2019-11-21 19:52:00')),
#  (47.284915924072266, Timestamp('2019-11-21 20:17:00')),
#  (48.43403625488281, Timestamp('2019-11-21 20:58:00')),
#  (48.57768249511719, Timestamp('2019-11-21 21:22:00')),
#  (48.153602600097656, Timestamp('2019-11-21 21:46:00')),
#  (47.9005241394043, Timestamp('2019-11-21 22:11:00')),
#  (51.6009635925293, Timestamp('2019-11-21 23:38:00')),
#  (49.81572341918945, Timestamp('2019-11-22 00:02:00')),
#  (48.7281608581543, Timestamp('2019-11-22 00:26:00')),
#  (48.76236343383789, Timestamp('2019-11-22 00:49:00')),
#  (48.256202697753906, Timestamp('2019-11-22 01:16:00')),
#  (49.41215896606445, Timestamp('2019-11-22 01:38:00')),
#  (48.037322998046875, Timestamp('2019-11-22 02:02:00')),
#  (48.399845123291016, Timestamp('2019-11-22 02:27:00')),
#  (48.666603088378906, Timestamp('2019-11-22 03:04:00')),
#  (48.43403625488281, Timestamp('2019-11-22 03:28:00')),
#  (48.38615798950195, Timestamp('2019-11-22 03:52:00')),
#  (50.3697624206543, Timestamp('2019-11-22 04:15:00')),
#  (47.538002014160156, Timestamp('2019-11-22 04:41:00')),
#  (48.4887580871582, Timestamp('2019-11-22 05:25:00')),
#  (48.263038635253906, Timestamp('2019-11-22 05:49:00')),
#  (48.97439956665039, Timestamp('2019-11-22 06:14:00')),
#  (47.209678649902344, Timestamp('2019-11-22 06:41:00')),
#  (46.8403205871582, Timestamp('2019-11-22 07:05:00')),
#  (46.73088073730469, Timestamp('2019-11-22 07:31:00')),
#  (48.79655838012695, Timestamp('2019-11-22 12:17:00')),
#  (49.624202728271484, Timestamp('2019-11-22 13:34:00')),
#  (48.550323486328125, Timestamp('2019-11-22 13:59:00')),
#  (48.338279724121094, Timestamp('2019-11-22 14:23:00')),
#  (47.982601165771484, Timestamp('2019-11-22 14:50:00')),
#  (48.023643493652344, Timestamp('2019-11-22 15:14:00')),
#  (47.85264205932617, Timestamp('2019-11-22 15:40:00')),
#  (48.440879821777344, Timestamp('2019-11-22 16:04:00')),
#  (49.86360168457031, Timestamp('2019-11-22 16:27:00')),
#  (48.495601654052734, Timestamp('2019-11-22 16:52:00')),
#  (49.979881286621094, Timestamp('2019-11-22 17:15:00')),
#  (48.65291976928711, Timestamp('2019-11-22 17:40:00')),
#  (49.41215896606445, Timestamp('2019-11-22 18:05:00')),
#  (50.362918853759766, Timestamp('2019-11-22 18:29:00')),
#  (54.514801025390625, Timestamp('2019-11-22 18:54:00')),
#  (49.20696258544922, Timestamp('2019-11-22 19:19:00')),
#  (49.289039611816406, Timestamp('2019-11-22 19:44:00')),
#  (49.870445251464844, Timestamp('2019-11-22 20:08:00')),
#  (47.715843200683594, Timestamp('2019-11-22 20:35:00')),
#  (50.034603118896484, Timestamp('2019-11-22 20:58:00')),
#  (47.538002014160156, Timestamp('2019-11-22 21:23:00')),
#  (47.77055740356445, Timestamp('2019-11-22 21:48:00')),
#  (47.0660400390625, Timestamp('2019-11-22 22:14:00')),
#  (48.06467819213867, Timestamp('2019-11-22 22:55:00')),
#  (49.55580139160156, Timestamp('2019-11-22 23:19:00')),
#  (48.58452224731445, Timestamp('2019-11-22 23:44:00')),
#  (48.338279724121094, Timestamp('2019-11-23 00:08:00')),
#  (47.729522705078125, Timestamp('2019-11-23 00:31:00')),
#  (47.8731575012207, Timestamp('2019-11-23 00:55:00')),
#  (48.21516036987305, Timestamp('2019-11-23 01:48:00')),
#  (48.07151794433594, Timestamp('2019-11-23 02:11:00')),
#  (47.79792022705078, Timestamp('2019-11-23 02:35:00')),
#  (47.33279800415039, Timestamp('2019-11-23 02:59:00')),
#  (48.201480865478516, Timestamp('2019-11-23 03:57:00')),
#  (48.256202697753906, Timestamp('2019-11-23 04:20:00')),
#  (47.989444732666016, Timestamp('2019-11-23 04:44:00')),
#  (47.579036712646484, Timestamp('2019-11-23 05:09:00')),
#  (47.03184127807617, Timestamp('2019-11-23 05:34:00')),
#  (48.17412185668945, Timestamp('2019-11-23 06:12:00')),
#  (49.1043586730957, Timestamp('2019-11-23 06:37:00')),
#  (51.170040130615234, Timestamp('2019-11-23 07:01:00')),
#  (47.640602111816406, Timestamp('2019-11-23 07:26:00')),
#  (48.543479919433594, Timestamp('2019-11-23 07:49:00')),
#  (47.62008285522461, Timestamp('2019-11-23 08:14:00')),
#  (47.12076187133789, Timestamp('2019-11-23 08:39:00')),
#  (48.249359130859375, Timestamp('2019-11-23 09:35:00')),
#  (48.50244140625, Timestamp('2019-11-23 09:59:00')),
#  (49.1385612487793, Timestamp('2019-11-23 10:21:00')),
#  (48.76236343383789, Timestamp('2019-11-23 10:46:00')),
#  (48.87864303588867, Timestamp('2019-11-23 11:08:00')),
#  (48.693965911865234, Timestamp('2019-11-23 11:32:00')),
#  (48.769203186035156, Timestamp('2019-11-23 11:55:00')),
#  (47.91420364379883, Timestamp('2019-11-23 12:20:00')),
#  (47.750038146972656, Timestamp('2019-11-23 12:45:00')),
#  (47.305442810058594, Timestamp('2019-11-23 13:10:00')),
#  (48.59136199951172, Timestamp('2019-11-23 14:41:00')),
#  (48.11940002441406, Timestamp('2019-11-23 15:05:00')),
#  (47.818443298339844, Timestamp('2019-11-23 15:28:00')),
#  (47.03867721557617, Timestamp('2019-11-23 15:54:00')),
#  (48.153602600097656, Timestamp('2019-11-23 17:30:00')),
#  (48.085205078125, Timestamp('2019-11-23 17:54:00')),
#  (48.01679611206055, Timestamp('2019-11-23 18:17:00')),
#  (47.585880279541016, Timestamp('2019-11-23 18:42:00')),
#  (47.49696350097656, Timestamp('2019-11-23 19:07:00')),
#  (48.926517486572266, Timestamp('2019-11-23 20:10:00')),
#  ...]

# %%
A_Pair_Filt_List
# Out:
# [(45.0, Timestamp('2019-11-26 12:14:00')),
#  (101.0, Timestamp('2019-11-26 12:15:00')),
#  (159.0, Timestamp('2019-11-26 12:16:00')),
#  (215.0, Timestamp('2019-11-26 12:17:00')),
#  (273.0, Timestamp('2019-11-26 12:18:00')),
#  (328.0, Timestamp('2019-11-26 12:19:00')),
#  (387.0, Timestamp('2019-11-26 12:20:00')),
#  (409.0, Timestamp('2019-11-26 12:21:00')),
#  (409.0, Timestamp('2019-11-26 12:22:00')),
#  (409.0, Timestamp('2019-11-26 12:23:00')),
#  (409.0, Timestamp('2019-11-26 12:24:00')),
#  (409.0, Timestamp('2019-11-26 12:25:00')),
#  (409.0, Timestamp('2019-11-26 12:26:00')),
#  (409.0, Timestamp('2019-11-26 12:27:00')),
#  (409.0, Timestamp('2019-11-26 12:28:00')),
#  (409.0, Timestamp('2019-11-26 12:29:00')),
#  (409.0, Timestamp('2019-11-26 12:30:00')),
#  (409.0, Timestamp('2019-11-26 12:31:00')),
#  (409.0, Timestamp('2019-11-26 12:32:00')),
#  (409.0, Timestamp('2019-11-26 12:33:00')),
#  (409.0, Timestamp('2019-11-26 12:34:00'))]
