# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df = pd.read_excel('C:\\Users\\v.t.flores\\Documents\\Investigations\\106AG03 cut shaft\\ag03 investigatn 2019.xlsx',sheet_name=12)

# %%
df.head()
# Out:
#             Unnamed: 0    Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 0  2018-10-01 00:05:00           NaN           NaN           NaN
# 1  2018-11-01 00:00:00           NaN           NaN           NaN
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV
# 3  2018-10-01 00:05:00       90.1269         93.66       91.6815
# 4  2018-10-01 00:10:00       90.2239          93.7       91.7377
#
#      Unnamed: 4    Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
# 3       89.8887         90.08      288.084      270.336      253.836
# 4       89.8291         90.05      288.888       270.54       253.68
#
#     Unnamed: 9  ...  Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# 0          NaN  ...          max       RXTR2         min         max
# ...

# %%
df.drop(df.columns[10:], axis=1, inplace=True)

# %%
df.head()
# Out:
#             Unnamed: 0    Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 0  2018-10-01 00:05:00           NaN           NaN           NaN
# 1  2018-11-01 00:00:00           NaN           NaN           NaN
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV
# 3  2018-10-01 00:05:00       90.1269         93.66       91.6815
# 4  2018-10-01 00:10:00       90.2239          93.7       91.7377
#
#      Unnamed: 4    Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
# 3       89.8887         90.08      288.084      270.336      253.836
# 4       89.8291         90.05      288.888       270.54       253.68
#
#     Unnamed: 9
# 0          NaN
# 1          NaN
# 2  106PI005.PV
# 3      234.948
# 4      235.032

# %%
df.drop(df.index[[0,1]], axis=0).head()
# Out:
#             Unnamed: 0    Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV
# 3  2018-10-01 00:05:00       90.1269         93.66       91.6815
# 4  2018-10-01 00:10:00       90.2239          93.7       91.7377
# 5  2018-10-01 00:15:00        90.069         93.73       91.7127
# 6  2018-10-01 00:20:00       89.8494         93.89       91.7796
#
#      Unnamed: 4    Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
# 3       89.8887         90.08      288.084      270.336      253.836
# 4       89.8291         90.05      288.888       270.54       253.68
# 5       89.7475         89.95        288.3      269.904      253.584
# 6       89.7781         89.68      288.492      270.144      253.764
#
#     Unnamed: 9
# 2  106PI005.PV
# 3      234.948
# 4      235.032
# 5      234.672
# 6      234.708

# %%
df.columns = df.iloc[2]

# %%
df.head()
# Out:
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV  \
# 0  2018-10-01 00:05:00           NaN           NaN           NaN
# 1  2018-11-01 00:00:00           NaN           NaN           NaN
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV
# 3  2018-10-01 00:05:00       90.1269         93.66       91.6815
# 4  2018-10-01 00:10:00       90.2239          93.7       91.7377
#
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
# 3       89.8887         90.08      288.084      270.336      253.836
# 4       89.8291         90.05      288.888       270.54       253.68
#
# 2  106PI005.PV
# 0          NaN
# 1          NaN
# 2  106PI005.PV
# 3      234.948
# 4      235.032

# %%
df.head()
# Out:
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV  \
# 0  2018-10-01 00:05:00           NaN           NaN           NaN
# 1  2018-11-01 00:00:00           NaN           NaN           NaN
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV
# 3  2018-10-01 00:05:00       90.1269         93.66       91.6815
# 4  2018-10-01 00:10:00       90.2239          93.7       91.7377
#
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
# 3       89.8887         90.08      288.084      270.336      253.836
# 4       89.8291         90.05      288.888       270.54       253.68
#
# 2  106PI005.PV
# 0          NaN
# 1          NaN
# 2  106PI005.PV
# 3      234.948
# 4      235.032

# %%
df[df.index[0]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-9d8678e0ce89> in <module>
# ----> 1 df[df.index[0]]
#
# ...

# %%
#df.set_index('time', inplace=True)

# %%
df.head()
# Out:
# 2                    106LIC003@PV  106LIC004@PV  106LIC005@PV  106LIC006@PV  \
# time
# 2018-10-01 00:05:00           NaN           NaN           NaN           NaN
# 2018-11-01 00:00:00           NaN           NaN           NaN           NaN
# time                 106LIC003@PV  106LIC004@PV  106LIC005@PV  106LIC006@PV
# 2018-10-01 00:05:00       90.1269         93.66       91.6815       89.8887
# 2018-10-01 00:10:00       90.2239          93.7       91.7377       89.8291
#
# 2                    106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV  \
# time
# 2018-10-01 00:05:00           NaN          NaN          NaN          NaN
# 2018-11-01 00:00:00           NaN          NaN          NaN          NaN
# time                 106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
# 2018-10-01 00:05:00         90.08      288.084      270.336      253.836
# 2018-10-01 00:10:00         90.05      288.888       270.54       253.68
#
# 2                    106PI005.PV
# time
# ...

# %%
df.describe()
# Out:
# 2                      time  106LIC003@PV  106LIC004@PV  106LIC005@PV  \
# count                  8925   8923.000000   8923.000000   8923.000000
# unique                 8924   6188.000000    574.000000   8810.000000
# top     2018-10-01 00:05:00     88.860001     92.860001     90.732346
# freq                      2     43.000000    132.000000      8.000000
#
# 2       106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV  \
# count    8923.000000   8923.000000  8928.000000  8928.000000  8928.000000
# unique   8856.000000    580.000000  7066.000000  7188.000000  7357.000000
# top        91.313057     89.209999    99.059998   102.863998   101.184006
# freq        2.000000    104.000000     8.000000     9.000000    10.000000
#
# 2       106PI005.PV
# count   8928.000000
# unique  7161.000000
# top      110.580002
# freq      11.000000

# %%
df.columns.values
# Out:
# array(['time', '106LIC003@PV', '106LIC004@PV', '106LIC005@PV',
#        '106LIC006@PV', '106LT003B@PV', '106PI002.PV', '106PI003.PV',
#        '106PI004.PV', '106PI005.PV'], dtype=object)

# %%
df.columns
# Out:
# Index(['time', '106LIC003@PV', '106LIC004@PV', '106LIC005@PV', '106LIC006@PV',
#        '106LT003B@PV', '106PI002.PV', '106PI003.PV', '106PI004.PV',
#        '106PI005.PV'],
#       dtype='object', name=2)

# %%
levels = ['106LIC003@PV', '106LIC004@PV', '106LIC005@PV','106LIC006@PV', '106LT003B@PV']
df[levels].head()
# Out:
# 2  106LIC003@PV  106LIC004@PV  106LIC005@PV  106LIC006@PV  106LT003B@PV
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2  106LIC003@PV  106LIC004@PV  106LIC005@PV  106LIC006@PV  106LT003B@PV
# 3       90.1269         93.66       91.6815       89.8887         90.08
# 4       90.2239          93.7       91.7377       89.8291         90.05

# %%
df.iloc[0:3]
# Out:
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV  \
# 0  2018-10-01 00:05:00           NaN           NaN           NaN
# 1  2018-11-01 00:00:00           NaN           NaN           NaN
# 2                 time  106LIC003@PV  106LIC004@PV  106LIC005@PV
#
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV  \
# 0           NaN           NaN          NaN          NaN          NaN
# 1           NaN           NaN          NaN          NaN          NaN
# 2  106LIC006@PV  106LT003B@PV  106PI002.PV  106PI003.PV  106PI004.PV
#
# 2  106PI005.PV
# 0          NaN
# 1          NaN
# 2  106PI005.PV

# %%
df.loc[25:30]
# Out:
# 2                  time 106LIC003@PV 106LIC004@PV 106LIC005@PV 106LIC006@PV  \
# 25  2018-10-01 01:55:00      89.5063        93.63      92.2106      89.9864
# 26  2018-10-01 02:00:00      89.5416        93.56      92.3004      90.0387
# 27  2018-10-01 02:05:00      89.4067        93.51      92.3392       90.076
# 28  2018-10-01 02:10:00      89.5796        93.44      92.3362      90.0383
# 29  2018-10-01 02:15:00      89.4079        93.57      92.3476      90.1344
# 30  2018-10-01 02:20:00      89.5062        93.47      92.3797      90.1767
#
# 2  106LT003B@PV 106PI002.PV 106PI003.PV 106PI004.PV 106PI005.PV
# 25        89.23     289.152     270.048     253.956      234.96
# 26        89.38     288.408     270.192     253.668     234.756
# 27        89.28     288.816     270.336     253.584       234.6
# 28        89.39      288.24     269.364     253.368     234.264
# 29        89.34     289.212     270.768     253.836      234.78
# ...

# %%
df['106LIC004@PV'] = pd.to_numeric(df['106LIC004@PV'], errors='coerce', downcast=None)

# %%
df['106LIC003@PV'] = pd.to_numeric(df['106LIC003@PV'], errors='coerce', downcast=None)

# %%
df[(df['106LIC004@PV']>90
   ) & 
    (df['106LIC003@PV']>90
    )
  ].head()
# Out:
# 2                  time  106LIC003@PV  106LIC004@PV 106LIC005@PV 106LIC006@PV  \
# 3   2018-10-01 00:05:00     90.126938     93.660004      91.6815      89.8887
# 4   2018-10-01 00:10:00     90.223900     93.699997      91.7377      89.8291
# 5   2018-10-01 00:15:00     90.069000     93.730003      91.7127      89.7475
# 77  2018-10-01 06:15:00     90.548996     90.430000      89.2934      87.2204
# 78  2018-10-01 06:20:00     92.098991     90.559998      89.7162      87.7588
#
# 2  106LT003B@PV 106PI002.PV 106PI003.PV 106PI004.PV 106PI005.PV
# 3         90.08     288.084     270.336     253.836     234.948
# 4         90.05     288.888      270.54      253.68     235.032
# 5         89.95       288.3     269.904     253.584     234.672
# 77        90.27     256.968      243.96     231.168     215.604
# 78        91.68      258.78      248.22     236.796     222.924

# %%
df['time']
# Out:
# 0       2018-10-01 00:05:00
# 1       2018-11-01 00:00:00
# 2                      time
# 3       2018-10-01 00:05:00
# 4       2018-10-01 00:10:00
#                ...
# 8925                    NaN
# 8926                    NaN
# 8927                    NaN
# 8928                    NaN
# 8929                    NaN
# Name: time, Length: 8930, dtype: object

# %%
df['time'] = pd.to_datetime(df['time'], errors='coerce')

# %%
df['time'].head()
# Out:
# 0   2018-10-01 00:05:00
# 1   2018-11-01 00:00:00
# 2                   NaT
# 3   2018-10-01 00:05:00
# 4   2018-10-01 00:10:00
# Name: time, dtype: datetime64[ns]

# %%
df['time'].dt.month
# Out:
# 0       10.0
# 1       11.0
# 2        NaN
# 3       10.0
# 4       10.0
#         ...
# 8925     NaN
# 8926     NaN
# 8927     NaN
# 8928     NaN
# 8929     NaN
# Name: time, Length: 8930, dtype: float64

# %%
df[df['time'].dt.month == 10].mode()
# Out:
# 2                 time  106LIC003@PV  106LIC004@PV 106LIC005@PV 106LIC006@PV  \
# 0  2018-10-01 00:05:00     88.860001     92.860001      74.6501      88.1403
# 1                  NaT           NaN           NaN      90.7323      88.1417
# 2                  NaT           NaN           NaN          NaN      88.3842
# 3                  NaT           NaN           NaN          NaN      88.4153
# 4                  NaT           NaN           NaN          NaN      88.4227
# ..                 ...           ...           ...          ...          ...
# 62                 NaT           NaN           NaN          NaN      92.0715
# 63                 NaT           NaN           NaN          NaN      92.2488
# 64                 NaT           NaN           NaN          NaN       92.508
# 65                 NaT           NaN           NaN          NaN       92.537
# 66                 NaT           NaN           NaN          NaN      92.9552
#
# ...

# %%
df[['106LIC003@PV','106LIC004@PV']].mode()
# Out:
# 2  106LIC003@PV  106LIC004@PV
# 0     88.860001     92.860001

# %%
df.groupby(df['time'].dt.day==5).mean()
# Out:
# 2      106LIC003@PV  106LIC004@PV
# time
# False      89.27725     92.083882
# True       90.28228     92.846910

# %%
df['106LIC006@PV'] = pd.to_numeric(df['106LIC006@PV'], errors='coerce')

# %%
df[['106LIC003@PV','106LIC004@PV'].mode()

# %%
df.groupby(['106LIC003@PV','106LIC004@PV'])['106LIC006@PV'].mean().head()
# Out:
# 106LIC003@PV  106LIC004@PV
# 81.515007     87.860001       87
# 81.515244     87.860001       87
# 81.515427     87.269997       87
# 81.515808     87.269997       87
# 81.515877     87.820000       87
# Name: 106LIC006@PV, dtype: int64

# %%
df.groupby(["Country", "Region"]).agg(
                     {'Total':['sum', 'max'], 
                      'Quantity':'mean'})
