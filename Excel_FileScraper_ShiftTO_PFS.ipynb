# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from dateutil.parser import parse
from itertools import compress
from collections import OrderedDict
from datetime import date
import datetime
import re
from datetime import timedelta
import openpyxl
from sklearn.metrics import mean_squared_error
import plotly.express as px
import openpyxl
import os
import re
from datetime import date
import datetime

# %%
filepath_TO1 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\01 January\000 Shift Turnover'
filepath_TO2 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\02 February\000 Shift Turnover'
filepath_TO3 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\03 March\000 Shift Turnover'
filepath_TO4 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\04 April\000 Shift Turnover'
filepath_TO5 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\05 May\000 Shift Turnover'
filepath_TO6 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\06 June\000 Shift Turnover'
filepath_TO7 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover'
filepath_TO8 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\08 August\000 Shift Turnover'
filepath_TO9 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\09 September\000 Shift Turnover'
filepath_TO10 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\10 October\000 Shift Turnover'
filepath_TO11 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\11 November\000 Shift Turnover'
filepath_TO12 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\12 December\000 Shift Turnover'

filepath_turnOverList = [filepath_TO1, filepath_TO2, filepath_TO3, filepath_TO4, filepath_TO5, filepath_TO6, filepath_TO7, filepath_TO8, filepath_TO9, filepath_TO10, filepath_TO11, filepath_TO12]

# %%
columns = ['I','J']
def find_specific_cellMech(theFile, sheetname, keyword, filename):
    for row in range(50, 140):
        for column in columns:  # Here you can add or reduce the columns
            cell_name = "{}{}".format(column, row)
            #regex block. cellkeywords_regex contains the rules on which characters to match.
            #------------ keyword contains the word in string that we want to find in the excel file
            #------------ cellvalue contains the word in string from the cell in the excel file
            #------------ keywordLike is a list of all the individual character that matches the rules set in cellkeywords_regex
            #------------ newpumplike is the resulting string from the combined characters of keywordLike
            
            cellkeywords_regex = re.compile(r'[KURIFIX]', re.IGNORECASE| re.VERBOSE|re.DOTALL)
            keyword = keyword
            cell_value = str(theFile[sheetname][cell_name].value)
            keywordLike = cellkeywords_regex.findall(cell_value)
            newpumpLike = ''.join(keywordLike)
            if keyword in newpumpLike:
                print("{} : {} has value {}".format(filename, cell_name, theFile[sheetname][cell_name].value))

'''
def find_IN_xlsx_files(filepathfolder, keyword):
    #filepath is the folder where we will do the search. example r'D:\Data Science Training\spreadsheets'
    #keywordtoFind is the string regex pattern of the word we want to find
    for root, dirs, files in os.walk(filepathfolder): #input the folder filepath here
        for filename in files:
            try:
                if filename.endswith('.xlsx') or filename.endswith('.xlsm'): #if statement checking if the file type is excel
                    #print (os.path.join(root, filename))
                    #theFile = openpyxl.load_workbook(os.path.join(root, filename), read_only=True) 
                    theFile = pd.read_excel(os.path.join(root, filename)) 
                    #os.path.join(root, filename) means the complete path to the file including the excel file
                    #-------------------------------------------------allSheetNames = theFile.sheetnames
                    
                    print('.', end='')
                    if keyword in theFile:
                        print('{} found in {}'.format(str(keyword), str(filename)))
                    #-------------------------------------------------for sheetName in theFile.sheetnames:
                    
            except:
                print('Error found')
                pass
'''

def find_the_word(x):
    cellkeywords_regex = re.compile(r'[a-zA-Z]', re.IGNORECASE| re.VERBOSE|re.DOTALL)
    keyword = 'PFS'
    #cell_value = str(theFile[sheetname][cell_name].value)
    keywordLike = cellkeywords_regex.findall(str(x))
    keywordLike = ''.join(keywordLike)
    if keyword in keywordLike:
        #print(keywordLike)
        x = 1
        return x
    
def searchEntire_DF(df):
    for col in df.columns:
        df[col] = df[col].apply(find_the_word)
        if df[col].sum() > 1:
            print('found PFS')
            return 'found PFS'
            break
        else:
            print('.', end='')
    return df

def find_IN_xlsx_files(filepathfolder):
    #filepath is the folder where we will do the search. example r'D:\Data Science Training\spreadsheets'
    #keywordtoFind is the string regex pattern of the word we want to find
    for root, dirs, files in os.walk(filepathfolder): #input the folder filepath here
        for filename in files:
            try:
                if filename.endswith('.xlsx') or filename.endswith('.xlsm'): #if statement checking if the file type is excel
                    #print (os.path.join(root, filename))
                    #theFile = openpyxl.load_workbook(os.path.join(root, filename), read_only=True) 
                    theFile = pd.read_excel(os.path.join(root, filename)) 
                    #os.path.join(root, filename) means the complete path to the file including the excel file
                    found = searchEntire_DF(theFile)
                    
                    print('.', end='')
                    if found == 'found PFS':
                        print('PFS found in {}'.format(str(filename)))
                    #-------------------------------------------------for sheetName in theFile.sheetnames:
                    
            except:
                print('Error found')
                pass

# %%
filepath_T = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover'
print(datetime.datetime.now())
find_IN_xlsx_files(filepath_turnOverList[0])
print("\n{}".format(datetime.datetime.now()))
# Out:
# 2020-11-21 17:34:14.676231
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...............................................Error found
# ...

# %%
filepath_1 = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover\20200701 TNH 303 101 Shift Turnover.xlsm'
filepath_1
theFile = pd.read_excel(filepath_1)

searchEntire_DF(theFile)
# Out:
# ..............................................
#    MS OPERATION SUMMARY Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                  None       None       None       None       None
# 1                  None       None       None       None       None
# 2                  None       None       None       None       None
# 3                  None       None       None       None       None
# 4                  None       None       None       None       None
# 5                  None       None       None       None       None
# 6                  None       None       None       None       None
# 7                  None       None       None       None       None
# 8                  None       None       None       None       None
# 9                  None       None       None       None       None
# 10                 None       None       None       None       None
# 11                 None       None       None       None       None
# ...

# %%
import os
from os.path import join, getsize
for root, dirs, files in os.walk(filepath_T):
    #print(files)
    for filename in files:
            try:
                if filename.endswith('.xlsx') or filename.endswith('.xlsm'): #if statement checking if the file type is excel
                    print (os.path.join(root, filename))
                    theFile = pd.read_excel(os.path.join(root, filename)) 
                    print(len(theFile))
                    #os.path.join(root, filename) means the complete path to the file including the excel file
                    #found = PFS_searchEntire_DF(theFile)
                    
                    #print('.', end='')
                    #if found == 'found PFS':
                    #    print('PFS found in {}'.format(str(filename)))
                    #-------------------------------------------------for sheetName in theFile.sheetnames:
                    
            except:
                print('Error found')
                pass
# Out:
# \\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover\20200701 TNH 303 101 Shift Turnover.xlsm
# 31
# \\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover\20200702 TNH 303 101 Shift Turnover.xlsm
# 31
# \\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover\20200703 TNH 303 101 Shift Turnover.xlsm
# 31
# \\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover\20200704 TNH 303 101 Shift Turnover.xlsm
# 31
# ...

# %%
filename = r'\\THGOBNA002\thpal\05 Production\302 Management - Report\TNH-302-101 Shift Turnover (THPAL)\Production Daily Report\Process B\2020\07 July\000 Shift Turnover\20200705 TNH 303 101 Shift Turnover.xlsm'
theFile = pd.read_excel(filename)
searchEntire_DF(theFile)
# Out:
# ..............................................
#    MS OPERATION SUMMARY Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                  None       None       None       None       None
# 1                  None       None       None       None       None
# 2                  None       None       None       None       None
# 3                  None       None       None       None       None
# 4                  None       None       None       None       None
# 5                  None       None       None       None       None
# 6                  None       None       None       None       None
# 7                  None       None       None       None       None
# 8                  None       None       None       None       None
# 9                  None       None       None       None       None
# 10                 None       None       None       None       None
# 11                 None       None       None       None       None
# ...
